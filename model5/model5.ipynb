# %%
# -*- coding: utf-8 -*-
from __future__ import print_function, division

from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, average_precision_score
from skimage.transform import resize
import scipy.io

import matplotlib.pyplot as plt
import itertools
import numpy as np
import time
import shutil
import os
# Out:
# Using TensorFlow backend.

# %%
# Fixing random state for reproducibility
seed = 19960925
np.random.seed(seed)
img_rows = 32
img_cols = 32
channels = 3
num_classes = 2

# %%
def load_TMI_data():
    # Load the dataset
    dataset = scipy.io.loadmat('TMI2015/training/training.mat')

    # Split into train and test. Values are in range [0..1] as float64
    X_train = np.transpose(dataset['train_x'], (3, 0, 1, 2))
    y_train = list(dataset['train_y'][0])
    
    X_test = np.transpose(dataset['test_x'], (3, 0, 1, 2))
    y_test = list(dataset['test_y'][0])
    
    # Change shape and range. 
    y_train = np.asarray(y_train).reshape(-1, 1)
    y_test = np.asarray(y_test).reshape(-1, 1)

#   1-> 0 : Non-nucleus. 2 -> 1: Nucleus
    y_test -= 1
    y_train -= 1

    # Resize to 32x32
    X_train_resized = np.empty([X_train.shape[0], 32, 32, X_train.shape[3]])
    for i in range(X_train.shape[0]):
        X_train_resized[i] = resize(X_train[i], (32, 32, 3), mode='reflect')

    X_test_resized = np.empty([X_test.shape[0], 32, 32, X_test.shape[3]])
    for i in range(X_test.shape[0]):
        X_test_resized[i] = resize(X_test[i], (32, 32, 3), mode='reflect')

    #Plotting a sample data:
    r, c = 5, 5
    fig, axs = plt.subplots(r, c)
#
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(X_train_resized[np.random.randint(0,6000)])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("./TMI_generators_output/tmi_training_random_sample.png")
    plt.suptitle('Non-nuclei Training Sample - label = 1')
    plt.show()
#
    r, c = 5, 5
    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(X_train_resized[np.random.randint(6000,8000)])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("./TMI_generators_output/tmi_training_random_sample.png")
    plt.suptitle('Nuclei Training Sample - label = 2')
    plt.show()
    
    # Normalize images from [0..1] to [-1..1]
    X_train_resized = 2 * X_train_resized - 1
    X_test_resized = 2 * X_test_resized - 1

    return X_train_resized, y_train, X_test_resized, y_test

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def build_generator():
    # This model replaced any pooling layers with strided convolutions
    # Allowing it to learn its own spatial upsampling

    model = Sequential()

    model.add(Dense(128 * 8 * 8, activation="relu", input_dim=100))

    model.add(Reshape((8, 8, 128)))
    model.add(BatchNormalization(momentum=0.8))

    # fractionally-strided convolution, do not confuse with deconvolution operation
    model.add(UpSampling2D())
    model.add(Conv2D(128, kernel_size=3, padding="same"))

    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))

    model.add(UpSampling2D())
    model.add(Conv2D(64, kernel_size=3, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))

    model.add(Conv2D(channels, kernel_size=3, padding="same"))
    model.add(Activation("tanh"))
    model.summary()

    noise = Input(shape=(100,))
    img = model(noise)

    return Model(noise, img)

def build_discriminator():
    # This model replaced any pooling layers with strided convolutions
    # Allowing it to learn its own spatial downsampling
    img_shape = (img_rows, img_cols, channels)

    # A Sequential model is a linear stack of layers.
    model = Sequential()

    # Create a Sequential model by simply adding layers via the .add() method
    # 32 filters, 3x3 kernel size, stride 2, input_shape is 28x28x1, same: pad so the output and input size are equal
    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=img_shape, padding="same"))
    # f(x) = alpha * x for x < 0, f(x) = x for x >= 0.
    # Leaky rectified activation worked well, especially for higher resolution modeling.
    # This is in contrast to the original GAN paper, which used the maxout activation
    model.add(LeakyReLU(alpha=0.2))
    # drops 25% of the input units
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    #A zero-padding layer. Adds rows and columns of zeros to the image
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    # Normalize the activations of the previous layer at each batch to reduce its covariance shift,
    # i.e., the amount that the distribution of each layer shift around.

    # This helps deal with training problems that arise due to poor initialization and helps gradient flow in deeper models.
    # This proved critical to get deep generators to begin learning, preventing the generator from collapsing all samples
    # to a single point which is a common failure mode observed in GANs.
    #
    # Directly applying batchnorm to all layers, however, resulted in sample oscillation and model instability.
    # This was avoided by not applying batchnorm to the generator output layer and the discriminator input layer
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))

    model.add(Flatten())
    #model.summary()
#        plot_path = "discriminator.png"
#        plot_model(model, to_file=plot_path, show_shapes=True, show_layer_names=True)


    # instantiate a Keras tensor
    img = Input(shape=img_shape)
    features = model(img)

    # valid indicates if the image is real or fake
    valid = Dense(1, activation="sigmoid")(features)
    # iff the image is real, label indicates which type of image it is
    label = Dense(num_classes+1, activation="softmax")(features)

    # Given an img (x)  and a label(y), instantiate a Model.
    # Once instantiated, this model will include all layers required in the computation of y given x.
    return Model(img, [valid, label])

# %%
def train( X_train, y_train, X_test, y_test, epochs, batch_size, save_interval):

    # delete directory if exist and create it
    shutil.rmtree('TMI_generators_output', ignore_errors=True)
    os.makedirs("TMI_generators_output")

    half_batch = int(batch_size / 2)

    # Class weights:
    # To balance the difference in occurences of class labels.
    # 50% of labels that D trains on are 'fake'.
    # Weight = 1 / frequency
    cw1 = {0: 1, 1: 1}
    cw2 = {i: num_classes / half_batch for i in range(num_classes)}
    cw2[num_classes] = 1 / half_batch

    for epoch in range(epochs):
        # ---------------------
        #  Training the Discriminator
        # ---------------------

        # Select a random half batch of images
        idx = np.random.randint(0, X_train.shape[0], half_batch)
        imgs = X_train[idx]

        # Draw random samples from a Gaussian distribution.
        noise = np.random.normal(0, 1, (half_batch, 100))
        # Generate a half batch of new images
        gen_imgs = generator.predict(noise)

        valid = np.ones((half_batch, 1))
        fake = np.zeros((half_batch, 1))

        # Convert labels to categorical one-hot encoding
        labels = to_categorical(y_train[idx], num_classes=num_classes+1)
        fake_labels = to_categorical(np.full((half_batch, 1), num_classes), num_classes=num_classes+1)

        # Train the discriminator (real classified as ones and fakes as zeros)
        # train_on_batch: Single gradient update over one batch of samples
        d_loss_real = discriminator.train_on_batch(imgs, [valid, labels], class_weight=[cw1, cw2])
        d_loss_fake = discriminator.train_on_batch(gen_imgs, [fake, fake_labels], class_weight=[cw1, cw2])
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # ---------------------
        #  Training the Generator
        # ---------------------
        validity = np.ones((batch_size, 1))

        for i in range(10):
            noise = np.random.normal(0, 1, (batch_size, 100))
            # Train the generator (wants discriminator to mistake images as real)
            g_loss = combined.train_on_batch(noise, validity, class_weight=[cw1, cw2])

        training_history["D_loss"].append(d_loss[0]);
        training_history["D_acc"].append(100*d_loss[3]);
        training_history["G_loss"].append(g_loss);
        training_history["G_acc"].append(100*d_loss[4]);

        print ("%d: Training D [loss: %.4f, acc: %.2f%% ] - G [loss: %.4f, acc: %.2f%%]" % (epoch, d_loss[0], 100*d_loss[3], g_loss, 100*d_loss[4]))
        evaluate_discriminator(X_test, y_test)

        # If at save interval => save generated image samples
        if epoch % save_interval == 0:
            save_imgs(epoch)

# %%
def evaluate_discriminator( X_test, y_test):
    valid = np.ones((y_test.shape[0], 1))

    # Convert labels to categorical one-hot encoding
    labels = to_categorical(y_test, num_classes=num_classes+1)

    #  Evaluating the trained Discriminator
    scores = discriminator.evaluate(X_test, [valid, labels], verbose=0)

    print("Evaluating D [loss:  %.4f, bi-loss: %.4f, cat-loss: %.4f, bi-acc: %.2f%%, cat-acc: %.2f%%]\n" %
          (scores[0], scores[1], scores[2], scores[3]*100, scores[4]*100))
#        print("\nEvaluating D [loss:  %.4f, acc: %.2f%%]" % (scores[0], scores[3]*100))

    return (scores[0], scores[3]*100)

# %%
def save_imgs(epoch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, 100))
    gen_imgs = generator.predict(noise)

    # Rescale images from [-1..1] to [0..1] just to display purposes.
    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt, :,:])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("./TMI_generators_output/tmi_%d.png" % epoch)
    plt.close()

# %%
def save_model():

    def save(model, model_name):
        model_path = "./TMI_saved_models/%s.json" % model_name
        weights_path = "./TMI_saved_models/%s_weights.hdf5" % model_name
        options = {"file_arch": model_path,
                    "file_weight": weights_path}
        json_string = model.to_json()
        open(options['file_arch'], 'w').write(json_string)
        model.save_weights(options['file_weight'])

    shutil.rmtree('TMI_saved_models', ignore_errors=True)
    os.makedirs("TMI_saved_models")

    save(generator, "TMI_gan_generator")
    save(discriminator, "TMI_gan_discriminator")
    save(combined, "TMI_gan_adversarial")

# %%
def plot_training_history():
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    plt.title('Training History')
    # summarize history for G and D accuracy
    axs[0].plot(range(1,len(training_history['D_acc'])+1),training_history['D_acc'])
    axs[0].plot(range(1,len(training_history['G_acc'])+1),training_history['G_acc'])
    axs[0].set_title('D and G Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(training_history['D_acc'])+1),len(training_history['D_acc'])/10)
    axs[0].set_yticks([n for n in range(0, 101,10)])
    axs[0].legend(['Discriminator', 'Generator'], loc='best')

    # summarize history for G and D loss
    axs[1].plot(range(1,len(training_history['D_loss'])+1),training_history['D_loss'])
    axs[1].plot(range(1,len(training_history['G_loss'])+1),training_history['G_loss'])
    axs[1].set_title('D and G Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(training_history['G_loss'])+1),len(training_history['G_loss'])/10)
    axs[1].legend(['Discriminator', 'Generator'], loc='best')
    plt.show()

# %%
def predict( X_test, y_test):

    # Generating a predictions from the discriminator over the testing dataset
    y_pred = discriminator.predict(X_test)

    # Formating predictions to remove the one_hot_encoding format
    y_pred = np.argmax(y_pred[1][:,:-1], axis=1)

    print ('\nOverall accuracy: %f%% \n' % (accuracy_score(y_test, y_pred) * 100))
    print ('\nAveP: %f%% \n' % (average_precision_score(y_test, y_pred) * 100))

    # Calculating and ploting a Classification Report
    class_names = ['Non-nunclei', 'Nuclei']
    print("Classification report:\n %s\n"
          % (classification_report(y_test, y_pred, target_names=class_names)))

    # Calculating and ploting Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
#        print("Confusion matrix:\n%s" % cm)

    plt.figure()
    plot_confusion_matrix(cm, class_names, title='Confusion matrix, without normalization')

    plt.figure()
    plot_confusion_matrix(cm, class_names, normalize=True, title='Normalized confusion matrix')

# %%
training_history = {
        'D_loss': [],
        'D_acc': [],
        'G_loss': [],
        'G_acc': [],
        }
        # TMI input shape (after resized)is 32x32x3

        # While previous GAN work has used momentum to accelerate training, we used the Adam optimizer
        # (Kingma & Ba, 2014) with tuned hyperparameters. We found the suggested learning rate of 0.001,
        # to be too high, using 0.0002 instead. Additionally, we found leaving the momentum term β1 at the
        # suggested value of 0.9 resulted in training oscillation and instability while reducing it to 0.5 helped
        # stabilize training
optimizer = Adam(0.0002, 0.5)
#build the generator
generator = build_generator()

# The generator takes noise as input and generates imgs
z = Input(shape=(100,))
img = generator(z)

        # Build discriminator's model
discriminator = build_discriminator()
# Compile discriminator's model, i.e. define its learning process
# binary crossentropy is used to distinguish among real or fake samples
# categorical entropy is to distinguish among which real category is (nuclei or non-nuclei)
discriminator.compile(
        loss=['binary_crossentropy', 'categorical_crossentropy'],
        loss_weights=[0.5, 0.5],
        optimizer=optimizer,
        metrics=['accuracy'])
# For the combined model we will only train the generator
discriminator.trainable = False

# For the combined model we will only train the generator
discriminator.trainable = False
# The discriminator takes generated images as input and determines validity
valid, _ =discriminator(img)

# The combined model  (stacked generator and discriminator) takes
# noise as input => generates images => determines validity
combined = Model(z, valid)
combined.compile(
        loss=['binary_crossentropy'], 
        optimizer=optimizer)
# Out:
# WARNING:tensorflow:From c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8192)              827392
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         1731
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 3)         0
# =================================================================
# Total params: 1,051,779
# Trainable params: 1,051,139
# Non-trainable params: 640
# _________________________________________________________________
# WARNING:tensorflow:From c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
if __name__ == '__main__':

    X_train, y_train, X_test, y_test = load_TMI_data()

#    Instanciate a compiled model

    start = time.time()
    
    epochs=200
    # Fit/Train the model
    train(X_train, y_train, X_test, y_test, epochs, batch_size=32, save_interval=5)

    end = time.time()
    print ("\nTraining time: %0.1f minutes \n" % ((end-start) / 60))

    #saved the trained model
    save_model()

#    plot training graph
    plot_training_history()

#    evaluate the trained D model w.r.t unseen data (i.e. testing set)

    evaluate_discriminator(X_test, y_test)

    predict(X_test, y_test)
# Out:
# WARNING:tensorflow:From c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\keras\engine\training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 0: Training D [loss: 0.5442, acc: 34.38% ] - G [loss: 0.4980, acc: 21.88%]
# Evaluating D [loss:  0.8865, bi-loss: 0.6801, cat-loss: 1.0928, bi-acc: 99.60%, cat-acc: 48.20%]
#
# 1: Training D [loss: 0.5111, acc: 43.75% ] - G [loss: 0.6041, acc: 34.38%]
# Evaluating D [loss:  0.8889, bi-loss: 0.6850, cat-loss: 1.0929, bi-acc: 94.30%, cat-acc: 48.40%]
#
# 2: Training D [loss: 0.5106, acc: 37.50% ] - G [loss: 0.4673, acc: 28.12%]
# Evaluating D [loss:  0.8898, bi-loss: 0.6868, cat-loss: 1.0928, bi-acc: 85.90%, cat-acc: 49.40%]
#
# 3: Training D [loss: 0.5771, acc: 37.50% ] - G [loss: 0.5696, acc: 50.00%]
# Evaluating D [loss:  0.8878, bi-loss: 0.6861, cat-loss: 1.0895, bi-acc: 87.00%, cat-acc: 49.50%]
#
# 4: Training D [loss: 0.4968, acc: 53.12% ] - G [loss: 0.7140, acc: 31.25%]
# Evaluating D [loss:  0.8893, bi-loss: 0.6910, cat-loss: 1.0877, bi-acc: 63.30%, cat-acc: 49.80%]
#
# 5: Training D [loss: 0.4892, acc: 34.38% ] - G [loss: 0.9195, acc: 50.00%]
# Evaluating D [loss:  0.8899, bi-loss: 0.6920, cat-loss: 1.0878, bi-acc: 58.80%, cat-acc: 49.40%]
#
# 6: Training D [loss: 0.3829, acc: 65.62% ] - G [loss: 0.8063, acc: 40.62%]
# Evaluating D [loss:  0.8873, bi-loss: 0.6892, cat-loss: 1.0854, bi-acc: 75.00%, cat-acc: 63.50%]
#
# 7: Training D [loss: 0.3796, acc: 65.62% ] - G [loss: 1.0227, acc: 25.00%]
# Evaluating D [loss:  0.8857, bi-loss: 0.6893, cat-loss: 1.0821, bi-acc: 72.50%, cat-acc: 73.10%]
#
# 8: Training D [loss: 0.3362, acc: 65.62% ] - G [loss: 1.2363, acc: 56.25%]
# Evaluating D [loss:  0.8834, bi-loss: 0.6893, cat-loss: 1.0774, bi-acc: 72.10%, cat-acc: 79.10%]
#
# 9: Training D [loss: 0.3356, acc: 71.88% ] - G [loss: 1.2285, acc: 59.38%]
# Evaluating D [loss:  0.8809, bi-loss: 0.6864, cat-loss: 1.0755, bi-acc: 82.50%, cat-acc: 76.00%]
#
# 10: Training D [loss: 0.2645, acc: 78.12% ] - G [loss: 1.6428, acc: 71.88%]
# Evaluating D [loss:  0.8803, bi-loss: 0.6875, cat-loss: 1.0731, bi-acc: 73.50%, cat-acc: 66.10%]
#
# 11: Training D [loss: 0.2128, acc: 87.50% ] - G [loss: 1.0843, acc: 68.75%]
# Evaluating D [loss:  0.8791, bi-loss: 0.6850, cat-loss: 1.0732, bi-acc: 75.90%, cat-acc: 64.70%]
#
# 12: Training D [loss: 0.3198, acc: 65.62% ] - G [loss: 1.1030, acc: 71.88%]
# Evaluating D [loss:  0.8812, bi-loss: 0.6873, cat-loss: 1.0750, bi-acc: 69.00%, cat-acc: 65.70%]
#
# 13: Training D [loss: 0.2252, acc: 78.12% ] - G [loss: 1.2663, acc: 81.25%]
# Evaluating D [loss:  0.8877, bi-loss: 0.6959, cat-loss: 1.0794, bi-acc: 39.50%, cat-acc: 65.50%]
#
# 14: Training D [loss: 0.2803, acc: 78.12% ] - G [loss: 1.4415, acc: 68.75%]
# Evaluating D [loss:  0.8873, bi-loss: 0.6963, cat-loss: 1.0782, bi-acc: 37.40%, cat-acc: 69.70%]
#
# 15: Training D [loss: 0.3345, acc: 78.12% ] - G [loss: 1.1935, acc: 43.75%]
# Evaluating D [loss:  0.8858, bi-loss: 0.6961, cat-loss: 1.0755, bi-acc: 38.60%, cat-acc: 72.20%]
#
# 16: Training D [loss: 0.3717, acc: 62.50% ] - G [loss: 0.7844, acc: 50.00%]
# Evaluating D [loss:  0.8860, bi-loss: 0.6982, cat-loss: 1.0738, bi-acc: 26.60%, cat-acc: 70.70%]
#
# 17: Training D [loss: 0.4004, acc: 56.25% ] - G [loss: 1.4216, acc: 40.62%]
# Evaluating D [loss:  0.8982, bi-loss: 0.7188, cat-loss: 1.0777, bi-acc: 0.10%, cat-acc: 72.20%]
#
# 18: Training D [loss: 0.6123, acc: 34.38% ] - G [loss: 1.3418, acc: 46.88%]
# Evaluating D [loss:  0.8953, bi-loss: 0.7123, cat-loss: 1.0783, bi-acc: 0.70%, cat-acc: 72.20%]
#
# 19: Training D [loss: 0.5318, acc: 46.88% ] - G [loss: 1.0657, acc: 40.62%]
# Evaluating D [loss:  0.8937, bi-loss: 0.7111, cat-loss: 1.0762, bi-acc: 2.00%, cat-acc: 76.50%]
#
# 20: Training D [loss: 0.4640, acc: 50.00% ] - G [loss: 1.6619, acc: 40.62%]
# Evaluating D [loss:  0.8956, bi-loss: 0.7166, cat-loss: 1.0747, bi-acc: 1.40%, cat-acc: 76.90%]
#
# 21: Training D [loss: 0.3903, acc: 53.12% ] - G [loss: 1.2221, acc: 59.38%]
# Evaluating D [loss:  0.8918, bi-loss: 0.7094, cat-loss: 1.0742, bi-acc: 6.30%, cat-acc: 79.20%]
#
# 22: Training D [loss: 0.5118, acc: 46.88% ] - G [loss: 1.2514, acc: 62.50%]
# Evaluating D [loss:  0.8910, bi-loss: 0.7070, cat-loss: 1.0749, bi-acc: 11.40%, cat-acc: 71.10%]
#
# 23: Training D [loss: 0.7364, acc: 25.00% ] - G [loss: 1.5239, acc: 31.25%]
# Evaluating D [loss:  0.8878, bi-loss: 0.7043, cat-loss: 1.0713, bi-acc: 9.50%, cat-acc: 80.00%]
#
# 24: Training D [loss: 0.3224, acc: 65.62% ] - G [loss: 1.8486, acc: 46.88%]
# Evaluating D [loss:  0.8889, bi-loss: 0.7053, cat-loss: 1.0726, bi-acc: 6.40%, cat-acc: 78.90%]
#
# 25: Training D [loss: 0.3185, acc: 71.88% ] - G [loss: 1.4953, acc: 56.25%]
# Evaluating D [loss:  0.8840, bi-loss: 0.6974, cat-loss: 1.0707, bi-acc: 26.00%, cat-acc: 83.60%]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 26: Training D [loss: 0.3093, acc: 71.88% ] - G [loss: 1.6091, acc: 62.50%]
# Evaluating D [loss:  0.8855, bi-loss: 0.6991, cat-loss: 1.0719, bi-acc: 22.80%, cat-acc: 82.90%]
#
# 27: Training D [loss: 0.3071, acc: 71.88% ] - G [loss: 1.9231, acc: 62.50%]
# Evaluating D [loss:  0.8899, bi-loss: 0.7056, cat-loss: 1.0741, bi-acc: 12.00%, cat-acc: 75.00%]
#
# 28: Training D [loss: 0.2993, acc: 71.88% ] - G [loss: 1.9135, acc: 71.88%]
# Evaluating D [loss:  0.8891, bi-loss: 0.7039, cat-loss: 1.0743, bi-acc: 15.50%, cat-acc: 74.00%]
#
# 29: Training D [loss: 0.2984, acc: 78.12% ] - G [loss: 1.6490, acc: 71.88%]
# Evaluating D [loss:  0.8871, bi-loss: 0.7005, cat-loss: 1.0736, bi-acc: 22.50%, cat-acc: 75.00%]
#
# 30: Training D [loss: 0.3389, acc: 71.88% ] - G [loss: 2.3243, acc: 59.38%]
# Evaluating D [loss:  0.8904, bi-loss: 0.7070, cat-loss: 1.0739, bi-acc: 8.10%, cat-acc: 74.50%]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 31: Training D [loss: 0.3211, acc: 75.00% ] - G [loss: 1.3901, acc: 75.00%]
# Evaluating D [loss:  0.8841, bi-loss: 0.6964, cat-loss: 1.0718, bi-acc: 37.90%, cat-acc: 75.50%]
#
# 32: Training D [loss: 0.2514, acc: 71.88% ] - G [loss: 2.1362, acc: 65.62%]
# Evaluating D [loss:  0.8894, bi-loss: 0.7046, cat-loss: 1.0743, bi-acc: 13.10%, cat-acc: 76.80%]
#
# 33: Training D [loss: 0.2323, acc: 84.38% ] - G [loss: 2.3599, acc: 46.88%]
# Evaluating D [loss:  0.8889, bi-loss: 0.7050, cat-loss: 1.0728, bi-acc: 11.00%, cat-acc: 77.80%]
#
# 34: Training D [loss: 0.3874, acc: 56.25% ] - G [loss: 2.1925, acc: 56.25%]
# Evaluating D [loss:  0.8866, bi-loss: 0.7000, cat-loss: 1.0733, bi-acc: 20.60%, cat-acc: 79.00%]
#
# 35: Training D [loss: 0.3808, acc: 71.88% ] - G [loss: 2.5674, acc: 50.00%]
# Evaluating D [loss:  0.8875, bi-loss: 0.7001, cat-loss: 1.0750, bi-acc: 21.90%, cat-acc: 85.10%]
#
# 36: Training D [loss: 0.1601, acc: 96.88% ] - G [loss: 1.9105, acc: 56.25%]
# Evaluating D [loss:  0.8884, bi-loss: 0.7014, cat-loss: 1.0754, bi-acc: 19.20%, cat-acc: 81.10%]
#
# 37: Training D [loss: 0.6080, acc: 34.38% ] - G [loss: 1.4031, acc: 37.50%]
# Evaluating D [loss:  0.8822, bi-loss: 0.6935, cat-loss: 1.0708, bi-acc: 43.20%, cat-acc: 77.50%]
#
# 38: Training D [loss: 0.1392, acc: 96.88% ] - G [loss: 2.6082, acc: 56.25%]
# Evaluating D [loss:  0.8907, bi-loss: 0.7053, cat-loss: 1.0760, bi-acc: 6.80%, cat-acc: 73.80%]
#
# 39: Training D [loss: 0.3187, acc: 75.00% ] - G [loss: 1.7983, acc: 62.50%]
# Evaluating D [loss:  0.8864, bi-loss: 0.6986, cat-loss: 1.0742, bi-acc: 19.70%, cat-acc: 78.30%]
#
# 40: Training D [loss: 0.1607, acc: 90.62% ] - G [loss: 2.2164, acc: 68.75%]
# Evaluating D [loss:  0.8905, bi-loss: 0.7041, cat-loss: 1.0770, bi-acc: 7.50%, cat-acc: 76.10%]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 41: Training D [loss: 0.7154, acc: 21.88% ] - G [loss: 1.8440, acc: 28.12%]
# Evaluating D [loss:  0.8825, bi-loss: 0.6935, cat-loss: 1.0715, bi-acc: 42.40%, cat-acc: 83.30%]
#
# 42: Training D [loss: 0.4582, acc: 59.38% ] - G [loss: 2.4497, acc: 37.50%]
# Evaluating D [loss:  0.8841, bi-loss: 0.6955, cat-loss: 1.0727, bi-acc: 34.50%, cat-acc: 78.50%]
#
# 43: Training D [loss: 0.4978, acc: 53.12% ] - G [loss: 1.6341, acc: 56.25%]
# Evaluating D [loss:  0.8794, bi-loss: 0.6892, cat-loss: 1.0695, bi-acc: 65.30%, cat-acc: 72.70%]
#
# 44: Training D [loss: 0.2275, acc: 81.25% ] - G [loss: 2.2812, acc: 68.75%]
# Evaluating D [loss:  0.8848, bi-loss: 0.6968, cat-loss: 1.0728, bi-acc: 30.80%, cat-acc: 68.40%]
#
# 45: Training D [loss: 0.4120, acc: 59.38% ] - G [loss: 2.0334, acc: 65.62%]
# Evaluating D [loss:  0.8805, bi-loss: 0.6916, cat-loss: 1.0694, bi-acc: 58.30%, cat-acc: 70.80%]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 46: Training D [loss: 0.4808, acc: 56.25% ] - G [loss: 2.6508, acc: 40.62%]
# Evaluating D [loss:  0.8801, bi-loss: 0.6909, cat-loss: 1.0693, bi-acc: 64.40%, cat-acc: 75.10%]
#
# 47: Training D [loss: 0.3673, acc: 71.88% ] - G [loss: 2.4867, acc: 62.50%]
# Evaluating D [loss:  0.8739, bi-loss: 0.6807, cat-loss: 1.0672, bi-acc: 93.30%, cat-acc: 73.30%]
#
# 48: Training D [loss: 0.2440, acc: 78.12% ] - G [loss: 2.4526, acc: 50.00%]
# Evaluating D [loss:  0.8737, bi-loss: 0.6803, cat-loss: 1.0671, bi-acc: 90.30%, cat-acc: 76.10%]
#
# 49: Training D [loss: 0.4526, acc: 62.50% ] - G [loss: 2.3867, acc: 62.50%]
# Evaluating D [loss:  0.8723, bi-loss: 0.6786, cat-loss: 1.0660, bi-acc: 92.10%, cat-acc: 64.90%]
#
# 50: Training D [loss: 0.2148, acc: 81.25% ] - G [loss: 2.2299, acc: 81.25%]
# Evaluating D [loss:  0.8695, bi-loss: 0.6736, cat-loss: 1.0653, bi-acc: 98.30%, cat-acc: 57.80%]
#
# 51: Training D [loss: 0.2667, acc: 75.00% ] - G [loss: 2.0839, acc: 71.88%]
# Evaluating D [loss:  0.8709, bi-loss: 0.6757, cat-loss: 1.0661, bi-acc: 97.70%, cat-acc: 55.80%]
#
# 52: Training D [loss: 0.2268, acc: 87.50% ] - G [loss: 2.9762, acc: 81.25%]
# Evaluating D [loss:  0.8709, bi-loss: 0.6778, cat-loss: 1.0639, bi-acc: 95.90%, cat-acc: 60.10%]
#
# 53: Training D [loss: 0.5505, acc: 50.00% ] - G [loss: 2.9269, acc: 50.00%]
# Evaluating D [loss:  0.8695, bi-loss: 0.6781, cat-loss: 1.0610, bi-acc: 97.00%, cat-acc: 61.60%]
#
# 54: Training D [loss: 0.3407, acc: 78.12% ] - G [loss: 0.5173, acc: 56.25%]
# Evaluating D [loss:  0.8587, bi-loss: 0.6621, cat-loss: 1.0553, bi-acc: 100.00%, cat-acc: 57.40%]
#
# 55: Training D [loss: 0.6857, acc: 56.25% ] - G [loss: 3.2536, acc: 46.88%]
# Evaluating D [loss:  0.8755, bi-loss: 0.6876, cat-loss: 1.0633, bi-acc: 78.90%, cat-acc: 64.90%]
#
# 56: Training D [loss: 0.9276, acc: 31.25% ] - G [loss: 0.7497, acc: 31.25%]
# Evaluating D [loss:  0.8685, bi-loss: 0.6767, cat-loss: 1.0603, bi-acc: 98.80%, cat-acc: 59.80%]
#
# 57: Training D [loss: 0.6861, acc: 34.38% ] - G [loss: 1.2357, acc: 43.75%]
# Evaluating D [loss:  0.8741, bi-loss: 0.6854, cat-loss: 1.0627, bi-acc: 83.50%, cat-acc: 59.20%]
#
# 58: Training D [loss: 0.5456, acc: 53.12% ] - G [loss: 0.4669, acc: 62.50%]
# Evaluating D [loss:  0.8763, bi-loss: 0.6891, cat-loss: 1.0635, bi-acc: 65.30%, cat-acc: 59.50%]
#
# 59: Training D [loss: 0.8059, acc: 25.00% ] - G [loss: 0.0814, acc: 31.25%]
# Evaluating D [loss:  0.8847, bi-loss: 0.7017, cat-loss: 1.0676, bi-acc: 18.10%, cat-acc: 67.40%]
#
# 60: Training D [loss: 1.8650, acc: 3.12% ] - G [loss: 0.1476, acc: 21.88%]
# Evaluating D [loss:  0.8878, bi-loss: 0.7104, cat-loss: 1.0653, bi-acc: 3.10%, cat-acc: 74.60%]
#
# 61: Training D [loss: 1.2741, acc: 3.12% ] - G [loss: 0.4520, acc: 28.12%]
# Evaluating D [loss:  0.8931, bi-loss: 0.7199, cat-loss: 1.0663, bi-acc: 0.60%, cat-acc: 74.70%]
#
# 62: Training D [loss: 0.8693, acc: 9.38% ] - G [loss: 1.1669, acc: 34.38%]
# Evaluating D [loss:  0.9003, bi-loss: 0.7311, cat-loss: 1.0694, bi-acc: 0.60%, cat-acc: 78.10%]
#
# 63: Training D [loss: 0.9525, acc: 18.75% ] - G [loss: 0.9739, acc: 37.50%]
# Evaluating D [loss:  0.9033, bi-loss: 0.7354, cat-loss: 1.0712, bi-acc: 0.00%, cat-acc: 72.50%]
#
# 64: Training D [loss: 0.6812, acc: 28.12% ] - G [loss: 0.6993, acc: 53.12%]
# Evaluating D [loss:  0.9002, bi-loss: 0.7303, cat-loss: 1.0701, bi-acc: 0.20%, cat-acc: 68.50%]
#
# 65: Training D [loss: 0.8218, acc: 28.12% ] - G [loss: 0.7540, acc: 21.88%]
# Evaluating D [loss:  0.8993, bi-loss: 0.7279, cat-loss: 1.0706, bi-acc: 0.00%, cat-acc: 66.40%]
#
# 66: Training D [loss: 0.6509, acc: 37.50% ] - G [loss: 0.8979, acc: 40.62%]
# Evaluating D [loss:  0.9050, bi-loss: 0.7354, cat-loss: 1.0746, bi-acc: 0.00%, cat-acc: 63.60%]
#
# 67: Training D [loss: 0.6962, acc: 28.12% ] - G [loss: 0.8921, acc: 34.38%]
# Evaluating D [loss:  0.9068, bi-loss: 0.7372, cat-loss: 1.0765, bi-acc: 0.00%, cat-acc: 61.60%]
#
# 68: Training D [loss: 0.6853, acc: 28.12% ] - G [loss: 0.8609, acc: 46.88%]
# Evaluating D [loss:  0.9100, bi-loss: 0.7431, cat-loss: 1.0768, bi-acc: 0.00%, cat-acc: 60.40%]
#
# 69: Training D [loss: 0.4680, acc: 50.00% ] - G [loss: 0.7751, acc: 50.00%]
# Evaluating D [loss:  0.9101, bi-loss: 0.7457, cat-loss: 1.0746, bi-acc: 0.00%, cat-acc: 62.70%]
#
# 70: Training D [loss: 0.7211, acc: 28.12% ] - G [loss: 0.7823, acc: 28.12%]
# Evaluating D [loss:  0.9105, bi-loss: 0.7485, cat-loss: 1.0725, bi-acc: 0.00%, cat-acc: 67.50%]
#
# 71: Training D [loss: 0.7185, acc: 28.12% ] - G [loss: 1.1483, acc: 50.00%]
# Evaluating D [loss:  0.9155, bi-loss: 0.7543, cat-loss: 1.0768, bi-acc: 0.00%, cat-acc: 60.70%]
#
# 72: Training D [loss: 0.7189, acc: 34.38% ] - G [loss: 0.7033, acc: 43.75%]
# Evaluating D [loss:  0.9143, bi-loss: 0.7504, cat-loss: 1.0782, bi-acc: 0.00%, cat-acc: 59.00%]
#
# 73: Training D [loss: 0.6571, acc: 31.25% ] - G [loss: 0.9983, acc: 53.12%]
# Evaluating D [loss:  0.9148, bi-loss: 0.7519, cat-loss: 1.0778, bi-acc: 0.00%, cat-acc: 62.00%]
#
# 74: Training D [loss: 0.5831, acc: 21.88% ] - G [loss: 0.9274, acc: 43.75%]
# Evaluating D [loss:  0.9119, bi-loss: 0.7481, cat-loss: 1.0758, bi-acc: 0.00%, cat-acc: 65.40%]
#
# 75: Training D [loss: 0.5964, acc: 28.12% ] - G [loss: 1.1333, acc: 46.88%]
# Evaluating D [loss:  0.9124, bi-loss: 0.7487, cat-loss: 1.0762, bi-acc: 0.00%, cat-acc: 61.60%]
#
# 76: Training D [loss: 0.4998, acc: 43.75% ] - G [loss: 0.8762, acc: 53.12%]
# Evaluating D [loss:  0.9159, bi-loss: 0.7527, cat-loss: 1.0790, bi-acc: 0.00%, cat-acc: 56.00%]
#
# 77: Training D [loss: 0.6645, acc: 31.25% ] - G [loss: 1.0541, acc: 43.75%]
# Evaluating D [loss:  0.9186, bi-loss: 0.7558, cat-loss: 1.0813, bi-acc: 0.00%, cat-acc: 51.80%]
#
# 78: Training D [loss: 0.6162, acc: 34.38% ] - G [loss: 1.1693, acc: 34.38%]
# Evaluating D [loss:  0.9207, bi-loss: 0.7605, cat-loss: 1.0809, bi-acc: 0.00%, cat-acc: 51.90%]
#
# 79: Training D [loss: 0.6289, acc: 43.75% ] - G [loss: 1.0402, acc: 28.12%]
# Evaluating D [loss:  0.9154, bi-loss: 0.7550, cat-loss: 1.0758, bi-acc: 0.00%, cat-acc: 62.50%]
#
# 80: Training D [loss: 0.6418, acc: 31.25% ] - G [loss: 0.8532, acc: 34.38%]
# Evaluating D [loss:  0.9103, bi-loss: 0.7463, cat-loss: 1.0742, bi-acc: 0.00%, cat-acc: 67.20%]
#
# 81: Training D [loss: 0.7083, acc: 18.75% ] - G [loss: 0.6316, acc: 46.88%]
# Evaluating D [loss:  0.9085, bi-loss: 0.7435, cat-loss: 1.0735, bi-acc: 0.00%, cat-acc: 70.20%]
#
# 82: Training D [loss: 0.5715, acc: 40.62% ] - G [loss: 0.6160, acc: 50.00%]
# Evaluating D [loss:  0.9096, bi-loss: 0.7456, cat-loss: 1.0735, bi-acc: 0.00%, cat-acc: 71.10%]
#
# 83: Training D [loss: 0.6629, acc: 37.50% ] - G [loss: 0.7766, acc: 53.12%]
# Evaluating D [loss:  0.9113, bi-loss: 0.7481, cat-loss: 1.0745, bi-acc: 0.00%, cat-acc: 68.60%]
#
# 84: Training D [loss: 0.6762, acc: 40.62% ] - G [loss: 0.9271, acc: 43.75%]
# Evaluating D [loss:  0.9078, bi-loss: 0.7421, cat-loss: 1.0736, bi-acc: 0.00%, cat-acc: 65.40%]
#
# 85: Training D [loss: 0.6926, acc: 18.75% ] - G [loss: 0.8853, acc: 50.00%]
# Evaluating D [loss:  0.9051, bi-loss: 0.7369, cat-loss: 1.0733, bi-acc: 0.00%, cat-acc: 63.40%]
#
# 86: Training D [loss: 0.4741, acc: 53.12% ] - G [loss: 0.7542, acc: 59.38%]
# Evaluating D [loss:  0.9083, bi-loss: 0.7422, cat-loss: 1.0744, bi-acc: 0.00%, cat-acc: 64.70%]
#
# 87: Training D [loss: 0.6677, acc: 31.25% ] - G [loss: 0.9744, acc: 31.25%]
# Evaluating D [loss:  0.9087, bi-loss: 0.7450, cat-loss: 1.0724, bi-acc: 0.00%, cat-acc: 71.50%]
#
# 88: Training D [loss: 0.4953, acc: 37.50% ] - G [loss: 1.0129, acc: 43.75%]
# Evaluating D [loss:  0.9086, bi-loss: 0.7449, cat-loss: 1.0724, bi-acc: 0.00%, cat-acc: 73.10%]
#
# 89: Training D [loss: 0.5965, acc: 28.12% ] - G [loss: 0.9977, acc: 31.25%]
# Evaluating D [loss:  0.9048, bi-loss: 0.7399, cat-loss: 1.0697, bi-acc: 0.00%, cat-acc: 77.80%]
#
# 90: Training D [loss: 0.6928, acc: 12.50% ] - G [loss: 0.8932, acc: 46.88%]
# Evaluating D [loss:  0.9036, bi-loss: 0.7377, cat-loss: 1.0696, bi-acc: 0.00%, cat-acc: 75.00%]
#
# 91: Training D [loss: 0.5166, acc: 37.50% ] - G [loss: 0.7315, acc: 50.00%]
# Evaluating D [loss:  0.9058, bi-loss: 0.7406, cat-loss: 1.0709, bi-acc: 0.00%, cat-acc: 70.50%]
#
# 92: Training D [loss: 0.6581, acc: 18.75% ] - G [loss: 0.6628, acc: 34.38%]
# Evaluating D [loss:  0.9063, bi-loss: 0.7410, cat-loss: 1.0716, bi-acc: 0.00%, cat-acc: 67.80%]
#
# 93: Training D [loss: 0.7143, acc: 12.50% ] - G [loss: 0.9213, acc: 37.50%]
# Evaluating D [loss:  0.9068, bi-loss: 0.7414, cat-loss: 1.0722, bi-acc: 0.00%, cat-acc: 72.60%]
#
# 94: Training D [loss: 0.4936, acc: 43.75% ] - G [loss: 0.9218, acc: 40.62%]
# Evaluating D [loss:  0.9053, bi-loss: 0.7410, cat-loss: 1.0696, bi-acc: 0.00%, cat-acc: 77.10%]
#
# 95: Training D [loss: 0.6411, acc: 28.12% ] - G [loss: 0.7171, acc: 46.88%]
# Evaluating D [loss:  0.9020, bi-loss: 0.7362, cat-loss: 1.0678, bi-acc: 0.00%, cat-acc: 77.30%]
#
# 96: Training D [loss: 0.6852, acc: 31.25% ] - G [loss: 0.7378, acc: 40.62%]
# Evaluating D [loss:  0.9015, bi-loss: 0.7353, cat-loss: 1.0678, bi-acc: 0.00%, cat-acc: 78.70%]
#
# 97: Training D [loss: 0.7182, acc: 12.50% ] - G [loss: 0.6900, acc: 62.50%]
# Evaluating D [loss:  0.9031, bi-loss: 0.7363, cat-loss: 1.0699, bi-acc: 0.00%, cat-acc: 73.70%]
#
# 98: Training D [loss: 0.6296, acc: 31.25% ] - G [loss: 0.6442, acc: 40.62%]
# Evaluating D [loss:  0.9056, bi-loss: 0.7409, cat-loss: 1.0704, bi-acc: 0.00%, cat-acc: 72.70%]
#
# 99: Training D [loss: 0.6190, acc: 21.88% ] - G [loss: 0.6766, acc: 40.62%]
# Evaluating D [loss:  0.9038, bi-loss: 0.7377, cat-loss: 1.0699, bi-acc: 0.00%, cat-acc: 73.30%]
#
# 100: Training D [loss: 0.8219, acc: 9.38% ] - G [loss: 0.7152, acc: 31.25%]
# Evaluating D [loss:  0.9011, bi-loss: 0.7315, cat-loss: 1.0706, bi-acc: 0.00%, cat-acc: 71.40%]
#
# 101: Training D [loss: 0.5564, acc: 37.50% ] - G [loss: 0.6542, acc: 31.25%]
# Evaluating D [loss:  0.9004, bi-loss: 0.7323, cat-loss: 1.0686, bi-acc: 0.00%, cat-acc: 73.00%]
#
# 102: Training D [loss: 0.6909, acc: 12.50% ] - G [loss: 0.7762, acc: 50.00%]
# Evaluating D [loss:  0.9017, bi-loss: 0.7349, cat-loss: 1.0685, bi-acc: 0.00%, cat-acc: 74.20%]
#
# 103: Training D [loss: 0.5813, acc: 37.50% ] - G [loss: 0.7676, acc: 56.25%]
# Evaluating D [loss:  0.9032, bi-loss: 0.7367, cat-loss: 1.0697, bi-acc: 0.00%, cat-acc: 73.60%]
#
# 104: Training D [loss: 0.6012, acc: 25.00% ] - G [loss: 0.7607, acc: 50.00%]
# Evaluating D [loss:  0.9030, bi-loss: 0.7382, cat-loss: 1.0677, bi-acc: 0.00%, cat-acc: 76.80%]
#
# 105: Training D [loss: 0.6686, acc: 25.00% ] - G [loss: 0.8263, acc: 34.38%]
# Evaluating D [loss:  0.9005, bi-loss: 0.7359, cat-loss: 1.0652, bi-acc: 0.00%, cat-acc: 78.60%]
#
# 106: Training D [loss: 0.6481, acc: 25.00% ] - G [loss: 0.8732, acc: 56.25%]
# Evaluating D [loss:  0.9026, bi-loss: 0.7405, cat-loss: 1.0647, bi-acc: 0.00%, cat-acc: 78.80%]
#
# 107: Training D [loss: 0.5042, acc: 40.62% ] - G [loss: 0.9396, acc: 50.00%]
# Evaluating D [loss:  0.9023, bi-loss: 0.7413, cat-loss: 1.0633, bi-acc: 0.00%, cat-acc: 80.20%]
#
# 108: Training D [loss: 0.5895, acc: 25.00% ] - G [loss: 0.6339, acc: 40.62%]
# Evaluating D [loss:  0.8969, bi-loss: 0.7332, cat-loss: 1.0606, bi-acc: 0.00%, cat-acc: 76.70%]
#
# 109: Training D [loss: 0.6214, acc: 34.38% ] - G [loss: 0.5795, acc: 37.50%]
# Evaluating D [loss:  0.8981, bi-loss: 0.7341, cat-loss: 1.0621, bi-acc: 0.00%, cat-acc: 77.20%]
#
# 110: Training D [loss: 0.6030, acc: 25.00% ] - G [loss: 0.7126, acc: 56.25%]
# Evaluating D [loss:  0.9003, bi-loss: 0.7363, cat-loss: 1.0644, bi-acc: 0.00%, cat-acc: 78.00%]
#
# 111: Training D [loss: 0.5519, acc: 31.25% ] - G [loss: 0.7253, acc: 40.62%]
# Evaluating D [loss:  0.8997, bi-loss: 0.7362, cat-loss: 1.0631, bi-acc: 0.00%, cat-acc: 79.90%]
#
# 112: Training D [loss: 0.7354, acc: 12.50% ] - G [loss: 0.8243, acc: 53.12%]
# Evaluating D [loss:  0.9003, bi-loss: 0.7351, cat-loss: 1.0655, bi-acc: 0.00%, cat-acc: 76.60%]
#
# 113: Training D [loss: 0.5342, acc: 37.50% ] - G [loss: 0.7347, acc: 50.00%]
# Evaluating D [loss:  0.8994, bi-loss: 0.7338, cat-loss: 1.0650, bi-acc: 0.00%, cat-acc: 77.40%]
#
# 114: Training D [loss: 0.5365, acc: 40.62% ] - G [loss: 0.6890, acc: 59.38%]
# Evaluating D [loss:  0.8985, bi-loss: 0.7323, cat-loss: 1.0648, bi-acc: 0.00%, cat-acc: 80.60%]
#
# 115: Training D [loss: 0.6982, acc: 15.62% ] - G [loss: 0.6882, acc: 43.75%]
# Evaluating D [loss:  0.8985, bi-loss: 0.7330, cat-loss: 1.0640, bi-acc: 0.00%, cat-acc: 82.80%]
#
# 116: Training D [loss: 0.5048, acc: 53.12% ] - G [loss: 0.8699, acc: 34.38%]
# Evaluating D [loss:  0.8989, bi-loss: 0.7337, cat-loss: 1.0641, bi-acc: 0.00%, cat-acc: 82.10%]
#
# 117: Training D [loss: 0.6285, acc: 25.00% ] - G [loss: 0.8307, acc: 21.88%]
# Evaluating D [loss:  0.8975, bi-loss: 0.7323, cat-loss: 1.0628, bi-acc: 0.00%, cat-acc: 80.80%]
#
# 118: Training D [loss: 0.5557, acc: 31.25% ] - G [loss: 0.9423, acc: 34.38%]
# Evaluating D [loss:  0.8963, bi-loss: 0.7298, cat-loss: 1.0628, bi-acc: 0.00%, cat-acc: 83.30%]
#
# 119: Training D [loss: 0.5812, acc: 28.12% ] - G [loss: 0.8969, acc: 37.50%]
# Evaluating D [loss:  0.8967, bi-loss: 0.7304, cat-loss: 1.0630, bi-acc: 0.00%, cat-acc: 79.60%]
#
# 120: Training D [loss: 0.5732, acc: 28.12% ] - G [loss: 0.8634, acc: 40.62%]
# Evaluating D [loss:  0.8957, bi-loss: 0.7287, cat-loss: 1.0626, bi-acc: 0.00%, cat-acc: 76.10%]
#
# 121: Training D [loss: 0.5888, acc: 31.25% ] - G [loss: 0.5791, acc: 31.25%]
# Evaluating D [loss:  0.8955, bi-loss: 0.7296, cat-loss: 1.0615, bi-acc: 0.00%, cat-acc: 73.70%]
#
# 122: Training D [loss: 0.5601, acc: 34.38% ] - G [loss: 0.5949, acc: 43.75%]
# Evaluating D [loss:  0.8960, bi-loss: 0.7309, cat-loss: 1.0611, bi-acc: 0.00%, cat-acc: 77.80%]
#
# 123: Training D [loss: 0.6059, acc: 37.50% ] - G [loss: 0.8962, acc: 37.50%]
# Evaluating D [loss:  0.8956, bi-loss: 0.7282, cat-loss: 1.0629, bi-acc: 0.00%, cat-acc: 79.90%]
#
# 124: Training D [loss: 0.5450, acc: 40.62% ] - G [loss: 0.6833, acc: 43.75%]
# Evaluating D [loss:  0.8948, bi-loss: 0.7271, cat-loss: 1.0625, bi-acc: 0.00%, cat-acc: 80.10%]
#
# 125: Training D [loss: 0.6244, acc: 15.62% ] - G [loss: 0.5335, acc: 43.75%]
# Evaluating D [loss:  0.8931, bi-loss: 0.7251, cat-loss: 1.0611, bi-acc: 0.00%, cat-acc: 84.60%]
#
# 126: Training D [loss: 0.5901, acc: 21.88% ] - G [loss: 0.7190, acc: 34.38%]
# Evaluating D [loss:  0.8938, bi-loss: 0.7262, cat-loss: 1.0613, bi-acc: 0.00%, cat-acc: 79.60%]
#
# 127: Training D [loss: 0.6049, acc: 21.88% ] - G [loss: 0.6884, acc: 53.12%]
# Evaluating D [loss:  0.8953, bi-loss: 0.7281, cat-loss: 1.0625, bi-acc: 0.00%, cat-acc: 75.60%]
#
# 128: Training D [loss: 0.6376, acc: 21.88% ] - G [loss: 0.7911, acc: 43.75%]
# Evaluating D [loss:  0.8955, bi-loss: 0.7281, cat-loss: 1.0629, bi-acc: 0.00%, cat-acc: 77.60%]
#
# 129: Training D [loss: 0.6233, acc: 34.38% ] - G [loss: 0.9477, acc: 37.50%]
# Evaluating D [loss:  0.8936, bi-loss: 0.7249, cat-loss: 1.0624, bi-acc: 0.00%, cat-acc: 79.20%]
#
# 130: Training D [loss: 0.5198, acc: 34.38% ] - G [loss: 0.7135, acc: 56.25%]
# Evaluating D [loss:  0.8904, bi-loss: 0.7213, cat-loss: 1.0595, bi-acc: 0.00%, cat-acc: 84.80%]
#
# 131: Training D [loss: 0.5511, acc: 34.38% ] - G [loss: 0.7517, acc: 50.00%]
# Evaluating D [loss:  0.8900, bi-loss: 0.7208, cat-loss: 1.0592, bi-acc: 0.00%, cat-acc: 82.40%]
#
# 132: Training D [loss: 0.6021, acc: 28.12% ] - G [loss: 0.6898, acc: 50.00%]
# Evaluating D [loss:  0.8893, bi-loss: 0.7196, cat-loss: 1.0591, bi-acc: 0.10%, cat-acc: 81.20%]
#
# 133: Training D [loss: 0.5091, acc: 31.25% ] - G [loss: 0.7743, acc: 43.75%]
# Evaluating D [loss:  0.8900, bi-loss: 0.7198, cat-loss: 1.0601, bi-acc: 0.00%, cat-acc: 77.60%]
#
# 134: Training D [loss: 0.5769, acc: 28.12% ] - G [loss: 0.8212, acc: 43.75%]
# Evaluating D [loss:  0.8922, bi-loss: 0.7235, cat-loss: 1.0608, bi-acc: 0.00%, cat-acc: 78.40%]
#
# 135: Training D [loss: 0.5722, acc: 25.00% ] - G [loss: 0.7569, acc: 43.75%]
# Evaluating D [loss:  0.8921, bi-loss: 0.7231, cat-loss: 1.0611, bi-acc: 0.00%, cat-acc: 79.20%]
#
# 136: Training D [loss: 0.5723, acc: 31.25% ] - G [loss: 0.8186, acc: 34.38%]
# Evaluating D [loss:  0.8907, bi-loss: 0.7225, cat-loss: 1.0589, bi-acc: 0.00%, cat-acc: 83.40%]
#
# 137: Training D [loss: 0.4888, acc: 34.38% ] - G [loss: 0.7344, acc: 50.00%]
# Evaluating D [loss:  0.8909, bi-loss: 0.7235, cat-loss: 1.0583, bi-acc: 0.00%, cat-acc: 86.00%]
#
# 138: Training D [loss: 0.6550, acc: 37.50% ] - G [loss: 0.7291, acc: 31.25%]
# Evaluating D [loss:  0.8887, bi-loss: 0.7205, cat-loss: 1.0570, bi-acc: 0.00%, cat-acc: 81.80%]
#
# 139: Training D [loss: 0.5783, acc: 37.50% ] - G [loss: 0.7349, acc: 37.50%]
# Evaluating D [loss:  0.8887, bi-loss: 0.7192, cat-loss: 1.0583, bi-acc: 0.00%, cat-acc: 78.70%]
#
# 140: Training D [loss: 0.6259, acc: 21.88% ] - G [loss: 0.7207, acc: 43.75%]
# Evaluating D [loss:  0.8891, bi-loss: 0.7184, cat-loss: 1.0598, bi-acc: 0.00%, cat-acc: 78.30%]
# 141: Training D [loss: 0.5405, acc: 25.00% ] - G [loss: 0.8350, acc: 56.25%]
# Evaluating D [loss:  0.8887, bi-loss: 0.7175, cat-loss: 1.0599, bi-acc: 0.00%, cat-acc: 81.40%]
#
# 142: Training D [loss: 0.5792, acc: 31.25% ] - G [loss: 0.6653, acc: 46.88%]
# Evaluating D [loss:  0.8878, bi-loss: 0.7160, cat-loss: 1.0595, bi-acc: 0.10%, cat-acc: 79.90%]
#
# 143: Training D [loss: 0.5490, acc: 28.12% ] - G [loss: 0.6243, acc: 40.62%]
# Evaluating D [loss:  0.8872, bi-loss: 0.7158, cat-loss: 1.0586, bi-acc: 0.10%, cat-acc: 77.00%]
#
# 144: Training D [loss: 0.6269, acc: 21.88% ] - G [loss: 0.5540, acc: 37.50%]
# Evaluating D [loss:  0.8890, bi-loss: 0.7184, cat-loss: 1.0597, bi-acc: 0.00%, cat-acc: 78.60%]
#
# 145: Training D [loss: 0.5180, acc: 37.50% ] - G [loss: 0.8498, acc: 34.38%]
# Evaluating D [loss:  0.8901, bi-loss: 0.7210, cat-loss: 1.0591, bi-acc: 0.00%, cat-acc: 82.20%]
#
# 146: Training D [loss: 0.5272, acc: 25.00% ] - G [loss: 0.7618, acc: 37.50%]
# Evaluating D [loss:  0.8905, bi-loss: 0.7220, cat-loss: 1.0590, bi-acc: 0.00%, cat-acc: 83.40%]
#
# 147: Training D [loss: 0.5725, acc: 28.12% ] - G [loss: 0.6685, acc: 53.12%]
# Evaluating D [loss:  0.8909, bi-loss: 0.7211, cat-loss: 1.0608, bi-acc: 0.00%, cat-acc: 82.40%]
#
# 148: Training D [loss: 0.5122, acc: 34.38% ] - G [loss: 0.5726, acc: 53.12%]
# Evaluating D [loss:  0.8903, bi-loss: 0.7192, cat-loss: 1.0614, bi-acc: 0.10%, cat-acc: 81.90%]
#
# 149: Training D [loss: 0.6675, acc: 12.50% ] - G [loss: 0.4505, acc: 50.00%]
# Evaluating D [loss:  0.8885, bi-loss: 0.7174, cat-loss: 1.0595, bi-acc: 0.10%, cat-acc: 82.90%]
#
# 150: Training D [loss: 0.6197, acc: 25.00% ] - G [loss: 0.5703, acc: 43.75%]
# Evaluating D [loss:  0.8881, bi-loss: 0.7168, cat-loss: 1.0593, bi-acc: 0.10%, cat-acc: 82.90%]
#
# 151: Training D [loss: 0.7360, acc: 12.50% ] - G [loss: 0.5828, acc: 43.75%]
# Evaluating D [loss:  0.8875, bi-loss: 0.7162, cat-loss: 1.0588, bi-acc: 0.10%, cat-acc: 82.00%]
#
# 152: Training D [loss: 0.5917, acc: 31.25% ] - G [loss: 0.8099, acc: 34.38%]
# Evaluating D [loss:  0.8881, bi-loss: 0.7171, cat-loss: 1.0591, bi-acc: 0.00%, cat-acc: 80.40%]
#
# 153: Training D [loss: 0.4956, acc: 34.38% ] - G [loss: 0.6903, acc: 53.12%]
# Evaluating D [loss:  0.8895, bi-loss: 0.7186, cat-loss: 1.0604, bi-acc: 0.00%, cat-acc: 75.90%]
#
# 154: Training D [loss: 0.5159, acc: 43.75% ] - G [loss: 0.6432, acc: 40.62%]
# Evaluating D [loss:  0.8888, bi-loss: 0.7176, cat-loss: 1.0600, bi-acc: 0.50%, cat-acc: 73.50%]
#
# 155: Training D [loss: 0.7520, acc: 25.00% ] - G [loss: 0.5795, acc: 28.12%]
# Evaluating D [loss:  0.8879, bi-loss: 0.7155, cat-loss: 1.0604, bi-acc: 0.50%, cat-acc: 78.10%]
#
# 156: Training D [loss: 0.5971, acc: 37.50% ] - G [loss: 0.6320, acc: 37.50%]
# Evaluating D [loss:  0.8892, bi-loss: 0.7167, cat-loss: 1.0617, bi-acc: 0.00%, cat-acc: 81.70%]
#
# 157: Training D [loss: 0.5259, acc: 40.62% ] - G [loss: 0.7032, acc: 40.62%]
# Evaluating D [loss:  0.8906, bi-loss: 0.7195, cat-loss: 1.0617, bi-acc: 0.00%, cat-acc: 82.20%]
#
# 158: Training D [loss: 0.6044, acc: 21.88% ] - G [loss: 0.5799, acc: 53.12%]
# Evaluating D [loss:  0.8903, bi-loss: 0.7189, cat-loss: 1.0618, bi-acc: 0.00%, cat-acc: 81.20%]
#
# 159: Training D [loss: 0.6033, acc: 31.25% ] - G [loss: 0.6953, acc: 31.25%]
# Evaluating D [loss:  0.8905, bi-loss: 0.7184, cat-loss: 1.0626, bi-acc: 0.00%, cat-acc: 76.00%]
#
# 160: Training D [loss: 0.5962, acc: 21.88% ] - G [loss: 0.6369, acc: 34.38%]
# Evaluating D [loss:  0.8890, bi-loss: 0.7171, cat-loss: 1.0609, bi-acc: 0.00%, cat-acc: 78.20%]
#
# 161: Training D [loss: 0.6242, acc: 15.62% ] - G [loss: 0.6670, acc: 40.62%]
# Evaluating D [loss:  0.8880, bi-loss: 0.7164, cat-loss: 1.0595, bi-acc: 0.00%, cat-acc: 80.50%]
#
# 162: Training D [loss: 0.5506, acc: 40.62% ] - G [loss: 0.7693, acc: 43.75%]
# Evaluating D [loss:  0.8874, bi-loss: 0.7154, cat-loss: 1.0594, bi-acc: 0.30%, cat-acc: 84.30%]
#
# 163: Training D [loss: 0.5494, acc: 28.12% ] - G [loss: 0.5504, acc: 50.00%]
# Evaluating D [loss:  0.8874, bi-loss: 0.7147, cat-loss: 1.0601, bi-acc: 0.70%, cat-acc: 84.60%]
#
# 164: Training D [loss: 0.4551, acc: 43.75% ] - G [loss: 0.6029, acc: 40.62%]
# Evaluating D [loss:  0.8881, bi-loss: 0.7154, cat-loss: 1.0608, bi-acc: 0.80%, cat-acc: 81.40%]
#
# 165: Training D [loss: 0.5564, acc: 34.38% ] - G [loss: 0.5743, acc: 50.00%]
# Evaluating D [loss:  0.8885, bi-loss: 0.7151, cat-loss: 1.0619, bi-acc: 0.80%, cat-acc: 80.50%]
#
# 166: Training D [loss: 0.6376, acc: 25.00% ] - G [loss: 0.6686, acc: 43.75%]
# Evaluating D [loss:  0.8874, bi-loss: 0.7131, cat-loss: 1.0618, bi-acc: 1.00%, cat-acc: 81.20%]
#
# 167: Training D [loss: 0.5858, acc: 25.00% ] - G [loss: 0.7755, acc: 40.62%]
# Evaluating D [loss:  0.8864, bi-loss: 0.7126, cat-loss: 1.0602, bi-acc: 0.90%, cat-acc: 81.60%]
#
# 168: Training D [loss: 0.4712, acc: 34.38% ] - G [loss: 0.6559, acc: 50.00%]
# Evaluating D [loss:  0.8854, bi-loss: 0.7118, cat-loss: 1.0590, bi-acc: 1.50%, cat-acc: 84.70%]
#
# 169: Training D [loss: 0.5244, acc: 21.88% ] - G [loss: 0.5294, acc: 53.12%]
# Evaluating D [loss:  0.8861, bi-loss: 0.7131, cat-loss: 1.0591, bi-acc: 1.20%, cat-acc: 85.10%]
#
# 170: Training D [loss: 0.6124, acc: 28.12% ] - G [loss: 0.5794, acc: 37.50%]
# Evaluating D [loss:  0.8870, bi-loss: 0.7139, cat-loss: 1.0601, bi-acc: 1.10%, cat-acc: 81.20%]
#
# 171: Training D [loss: 0.5809, acc: 34.38% ] - G [loss: 0.5763, acc: 40.62%]
# Evaluating D [loss:  0.8882, bi-loss: 0.7148, cat-loss: 1.0616, bi-acc: 1.00%, cat-acc: 78.50%]
#
# 172: Training D [loss: 0.5075, acc: 31.25% ] - G [loss: 0.5821, acc: 43.75%]
# Evaluating D [loss:  0.8890, bi-loss: 0.7154, cat-loss: 1.0627, bi-acc: 0.40%, cat-acc: 79.70%]
#
# 173: Training D [loss: 0.5225, acc: 34.38% ] - G [loss: 0.5981, acc: 34.38%]
# Evaluating D [loss:  0.8888, bi-loss: 0.7156, cat-loss: 1.0621, bi-acc: 0.10%, cat-acc: 78.60%]
#
# 174: Training D [loss: 0.5511, acc: 37.50% ] - G [loss: 0.7599, acc: 43.75%]
# Evaluating D [loss:  0.8874, bi-loss: 0.7143, cat-loss: 1.0605, bi-acc: 0.00%, cat-acc: 81.80%]
#
# 175: Training D [loss: 0.4509, acc: 37.50% ] - G [loss: 0.7812, acc: 50.00%]
# Evaluating D [loss:  0.8867, bi-loss: 0.7142, cat-loss: 1.0593, bi-acc: 0.10%, cat-acc: 83.40%]
#
# 176: Training D [loss: 0.4387, acc: 37.50% ] - G [loss: 0.7130, acc: 46.88%]
# Evaluating D [loss:  0.8864, bi-loss: 0.7138, cat-loss: 1.0590, bi-acc: 0.40%, cat-acc: 82.00%]
#
# 177: Training D [loss: 0.4538, acc: 40.62% ] - G [loss: 0.6580, acc: 62.50%]
# Evaluating D [loss:  0.8861, bi-loss: 0.7132, cat-loss: 1.0590, bi-acc: 0.90%, cat-acc: 80.60%]
#
# 178: Training D [loss: 0.5969, acc: 15.62% ] - G [loss: 0.7332, acc: 46.88%]
# Evaluating D [loss:  0.8868, bi-loss: 0.7137, cat-loss: 1.0599, bi-acc: 1.00%, cat-acc: 79.50%]
#
# 179: Training D [loss: 0.5386, acc: 37.50% ] - G [loss: 0.7473, acc: 40.62%]
# Evaluating D [loss:  0.8873, bi-loss: 0.7138, cat-loss: 1.0608, bi-acc: 0.30%, cat-acc: 80.40%]
#
# 180: Training D [loss: 0.4569, acc: 37.50% ] - G [loss: 0.7894, acc: 31.25%]
# Evaluating D [loss:  0.8875, bi-loss: 0.7140, cat-loss: 1.0610, bi-acc: 0.00%, cat-acc: 81.10%]
#
# 181: Training D [loss: 0.4810, acc: 40.62% ] - G [loss: 0.6521, acc: 53.12%]
# Evaluating D [loss:  0.8874, bi-loss: 0.7135, cat-loss: 1.0613, bi-acc: 0.10%, cat-acc: 81.40%]
#
# 182: Training D [loss: 0.4776, acc: 46.88% ] - G [loss: 0.6613, acc: 65.62%]
# Evaluating D [loss:  0.8880, bi-loss: 0.7153, cat-loss: 1.0606, bi-acc: 0.00%, cat-acc: 79.80%]
#
# 183: Training D [loss: 0.5719, acc: 25.00% ] - G [loss: 0.7166, acc: 43.75%]
# Evaluating D [loss:  0.8877, bi-loss: 0.7152, cat-loss: 1.0602, bi-acc: 0.00%, cat-acc: 77.20%]
#
# 184: Training D [loss: 0.5967, acc: 18.75% ] - G [loss: 0.5431, acc: 43.75%]
# Evaluating D [loss:  0.8873, bi-loss: 0.7145, cat-loss: 1.0602, bi-acc: 0.00%, cat-acc: 75.80%]
#
# 185: Training D [loss: 0.5345, acc: 37.50% ] - G [loss: 0.9382, acc: 40.62%]
# Evaluating D [loss:  0.8866, bi-loss: 0.7140, cat-loss: 1.0592, bi-acc: 0.00%, cat-acc: 79.10%]
#
# 186: Training D [loss: 0.5228, acc: 43.75% ] - G [loss: 0.7807, acc: 43.75%]
# Evaluating D [loss:  0.8855, bi-loss: 0.7116, cat-loss: 1.0593, bi-acc: 0.00%, cat-acc: 76.80%]
#
# 187: Training D [loss: 0.5143, acc: 31.25% ] - G [loss: 0.7646, acc: 50.00%]
# Evaluating D [loss:  0.8852, bi-loss: 0.7115, cat-loss: 1.0590, bi-acc: 0.20%, cat-acc: 77.60%]
#
# 188: Training D [loss: 0.5037, acc: 31.25% ] - G [loss: 0.6434, acc: 59.38%]
# Evaluating D [loss:  0.8853, bi-loss: 0.7114, cat-loss: 1.0592, bi-acc: 0.80%, cat-acc: 77.90%]
#
# 189: Training D [loss: 0.6090, acc: 15.62% ] - G [loss: 0.6597, acc: 50.00%]
# Evaluating D [loss:  0.8851, bi-loss: 0.7113, cat-loss: 1.0589, bi-acc: 0.60%, cat-acc: 79.10%]
#
# 190: Training D [loss: 0.5047, acc: 31.25% ] - G [loss: 0.7400, acc: 43.75%]
# Evaluating D [loss:  0.8856, bi-loss: 0.7121, cat-loss: 1.0591, bi-acc: 0.50%, cat-acc: 80.80%]
#
# 191: Training D [loss: 0.5424, acc: 25.00% ] - G [loss: 0.7742, acc: 50.00%]
# Evaluating D [loss:  0.8863, bi-loss: 0.7127, cat-loss: 1.0598, bi-acc: 0.30%, cat-acc: 80.00%]
#
# 192: Training D [loss: 0.6134, acc: 18.75% ] - G [loss: 0.7633, acc: 28.12%]
# Evaluating D [loss:  0.8853, bi-loss: 0.7116, cat-loss: 1.0589, bi-acc: 0.10%, cat-acc: 82.50%]
#
# 193: Training D [loss: 0.5737, acc: 34.38% ] - G [loss: 0.6434, acc: 34.38%]
# Evaluating D [loss:  0.8846, bi-loss: 0.7103, cat-loss: 1.0589, bi-acc: 0.30%, cat-acc: 81.70%]
#
# 194: Training D [loss: 0.5114, acc: 31.25% ] - G [loss: 0.7177, acc: 56.25%]
# Evaluating D [loss:  0.8849, bi-loss: 0.7091, cat-loss: 1.0606, bi-acc: 0.30%, cat-acc: 79.90%]
#
# 195: Training D [loss: 0.5658, acc: 21.88% ] - G [loss: 0.6347, acc: 56.25%]
# Evaluating D [loss:  0.8853, bi-loss: 0.7089, cat-loss: 1.0617, bi-acc: 0.20%, cat-acc: 78.10%]
#
# 196: Training D [loss: 0.5831, acc: 25.00% ] - G [loss: 0.7299, acc: 53.12%]
# Evaluating D [loss:  0.8853, bi-loss: 0.7087, cat-loss: 1.0619, bi-acc: 0.10%, cat-acc: 78.90%]
#
# 197: Training D [loss: 0.6336, acc: 25.00% ] - G [loss: 0.6150, acc: 28.12%]
# Evaluating D [loss:  0.8846, bi-loss: 0.7082, cat-loss: 1.0610, bi-acc: 0.90%, cat-acc: 78.70%]
#
# 198: Training D [loss: 0.4587, acc: 40.62% ] - G [loss: 0.6545, acc: 53.12%]
# Evaluating D [loss:  0.8847, bi-loss: 0.7080, cat-loss: 1.0615, bi-acc: 1.00%, cat-acc: 75.60%]
#
# 199: Training D [loss: 0.5565, acc: 28.12% ] - G [loss: 0.8605, acc: 40.62%]
# Evaluating D [loss:  0.8841, bi-loss: 0.7073, cat-loss: 1.0610, bi-acc: 1.20%, cat-acc: 75.80%]
#
#
# Training time: 32.5 minutes
# Evaluating D [loss:  0.8841, bi-loss: 0.7073, cat-loss: 1.0610, bi-acc: 1.20%, cat-acc: 75.80%]
#
#
# Overall accuracy: 75.800000%
#
#
# AveP: 75.700769%
#
# Classification report:
#                precision    recall  f1-score   support
#
#  Non-nunclei       0.67      1.00      0.80       500
#       Nuclei       1.00      0.52      0.68       500
#
#    micro avg       0.76      0.76      0.76      1000
#    macro avg       0.84      0.76      0.74      1000
# weighted avg       0.84      0.76      0.74      1000
