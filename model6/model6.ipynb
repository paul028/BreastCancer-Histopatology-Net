# %%
# -*- coding: utf-8 -*-
#no batch norm
from __future__ import print_function, division

from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, average_precision_score
from skimage.transform import resize
import scipy.io

import matplotlib.pyplot as plt
import itertools
import numpy as np
import time
import shutil
import os
# Out:
# Using TensorFlow backend.

# %%
# Fixing random state for reproducibility
seed = 19960925
np.random.seed(seed)
img_rows = 32
img_cols = 32
channels = 3
num_classes = 2

# %%
def load_TMI_data():
    # Load the dataset
    dataset = scipy.io.loadmat('TMI2015/training/training.mat')

    # Split into train and test. Values are in range [0..1] as float64
    X_train = np.transpose(dataset['train_x'], (3, 0, 1, 2))
    y_train = list(dataset['train_y'][0])
    
    X_test = np.transpose(dataset['test_x'], (3, 0, 1, 2))
    y_test = list(dataset['test_y'][0])
    
    # Change shape and range. 
    y_train = np.asarray(y_train).reshape(-1, 1)
    y_test = np.asarray(y_test).reshape(-1, 1)

#   1-> 0 : Non-nucleus. 2 -> 1: Nucleus
    y_test -= 1
    y_train -= 1

    # Resize to 32x32
    X_train_resized = np.empty([X_train.shape[0], 32, 32, X_train.shape[3]])
    for i in range(X_train.shape[0]):
        X_train_resized[i] = resize(X_train[i], (32, 32, 3), mode='reflect')

    X_test_resized = np.empty([X_test.shape[0], 32, 32, X_test.shape[3]])
    for i in range(X_test.shape[0]):
        X_test_resized[i] = resize(X_test[i], (32, 32, 3), mode='reflect')

    #Plotting a sample data:
    r, c = 5, 5
    fig, axs = plt.subplots(r, c)
#
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(X_train_resized[np.random.randint(0,6000)])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("./TMI_generators_output/tmi_training_random_sample.png")
    plt.suptitle('Non-nuclei Training Sample - label = 1')
    plt.show()
#
    r, c = 5, 5
    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(X_train_resized[np.random.randint(6000,8000)])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("./TMI_generators_output/tmi_training_random_sample.png")
    plt.suptitle('Nuclei Training Sample - label = 2')
    plt.show()
    
    # Normalize images from [0..1] to [-1..1]
    X_train_resized = 2 * X_train_resized - 1
    X_test_resized = 2 * X_test_resized - 1

    return X_train_resized, y_train, X_test_resized, y_test

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def build_generator():
    model = Sequential()

    model.add(Dense(128 * 8 * 8, activation="relu", input_dim=100))

    model.add(Reshape((8, 8, 128)))
    model.add(BatchNormalization(momentum=0.8))
    model.add(UpSampling2D())
    model.add(Conv2D(128, kernel_size=3, padding="same"))

    model.add(Activation("relu"))
    model.add(UpSampling2D())
    model.add(Conv2D(64, kernel_size=3, padding="same"))
    model.add(Activation("relu"))
    model.add(Conv2D(channels, kernel_size=3, padding="same"))
    model.add(Activation("tanh"))
    model.summary()

    noise = Input(shape=(100,))
    img = model(noise)

    return Model(noise, img)

def build_discriminator():
    img_shape = (img_rows, img_cols, channels)
    model = Sequential()
    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=img_shape, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.summary()

    img = Input(shape=img_shape)
    features = model(img)

    valid = Dense(1, activation="sigmoid")(features)
    label = Dense(num_classes+1, activation="softmax")(features)

    return Model(img, [valid, label])

# %%
def train( X_train, y_train, X_test, y_test, epochs, batch_size, save_interval):

    # delete directory if exist and create it
    shutil.rmtree('TMI_generators_output', ignore_errors=True)
    os.makedirs("TMI_generators_output")

    half_batch = int(batch_size / 2)

    # Class weights:
    # To balance the difference in occurences of class labels.
    # 50% of labels that D trains on are 'fake'.
    # Weight = 1 / frequency
    cw1 = {0: 1, 1: 1}
    cw2 = {i: num_classes / half_batch for i in range(num_classes)}
    cw2[num_classes] = 1 / half_batch

    for epoch in range(epochs):

        idx = np.random.randint(0, X_train.shape[0], half_batch)
        imgs = X_train[idx]

        # Draw random samples from a Gaussian distribution.
        noise = np.random.normal(0, 1, (half_batch, 100))
        # Generate a half batch of new images
        gen_imgs = generator.predict(noise)

        valid = np.ones((half_batch, 1))
        fake = np.zeros((half_batch, 1))

        # Convert labels to categorical one-hot encoding
        labels = to_categorical(y_train[idx], num_classes=num_classes+1)
        fake_labels = to_categorical(np.full((half_batch, 1), num_classes), num_classes=num_classes+1)

        d_loss_real = discriminator.train_on_batch(imgs, [valid, labels], class_weight=[cw1, cw2])
        d_loss_fake = discriminator.train_on_batch(gen_imgs, [fake, fake_labels], class_weight=[cw1, cw2])
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        validity = np.ones((batch_size, 1))

        for i in range(10):
            noise = np.random.normal(0, 1, (batch_size, 100))
            # Train the generator (wants discriminator to mistake images as real)
            g_loss = combined.train_on_batch(noise, validity, class_weight=[cw1, cw2])

        training_history["D_loss"].append(d_loss[0]);
        training_history["D_acc"].append(100*d_loss[3]);
        training_history["G_loss"].append(g_loss);
        training_history["G_acc"].append(100*d_loss[4]);

        print ("%d: Training D [loss: %.4f, acc: %.2f%% ] - G [loss: %.4f, acc: %.2f%%]" % (epoch, d_loss[0], 100*d_loss[3], g_loss, 100*d_loss[4]))
        evaluate_discriminator(X_test, y_test)

        # If at save interval => save generated image samples
        if epoch % save_interval == 0:
            save_imgs(epoch)

# %%
def evaluate_discriminator( X_test, y_test):
    valid = np.ones((y_test.shape[0], 1))

    # Convert labels to categorical one-hot encoding
    labels = to_categorical(y_test, num_classes=num_classes+1)

    #  Evaluating the trained Discriminator
    scores = discriminator.evaluate(X_test, [valid, labels], verbose=0)

    print("Evaluating D [loss:  %.4f, bi-loss: %.4f, cat-loss: %.4f, bi-acc: %.2f%%, cat-acc: %.2f%%]\n" %
          (scores[0], scores[1], scores[2], scores[3]*100, scores[4]*100))

    return (scores[0], scores[3]*100)

# %%
def save_imgs(epoch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, 100))
    gen_imgs = generator.predict(noise)

    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt, :,:])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("./TMI_generators_output/tmi_%d.png" % epoch)
    plt.close()

# %%
def save_model():

    def save(model, model_name):
        model_path = "./TMI_saved_models/%s.json" % model_name
        weights_path = "./TMI_saved_models/%s_weights.hdf5" % model_name
        options = {"file_arch": model_path,
                    "file_weight": weights_path}
        json_string = model.to_json()
        open(options['file_arch'], 'w').write(json_string)
        model.save_weights(options['file_weight'])

    shutil.rmtree('TMI_saved_models', ignore_errors=True)
    os.makedirs("TMI_saved_models")

    save(generator, "TMI_gan_generator")
    save(discriminator, "TMI_gan_discriminator")
    save(combined, "TMI_gan_adversarial")

# %%
def plot_training_history():
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    plt.title('Training History')
    # summarize history for G and D accuracy
    axs[0].plot(range(1,len(training_history['D_acc'])+1),training_history['D_acc'])
    axs[0].plot(range(1,len(training_history['G_acc'])+1),training_history['G_acc'])
    axs[0].set_title('D and G Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(training_history['D_acc'])+1),len(training_history['D_acc'])/10)
    axs[0].set_yticks([n for n in range(0, 101,10)])
    axs[0].legend(['Discriminator', 'Generator'], loc='best')

    axs[1].plot(range(1,len(training_history['D_loss'])+1),training_history['D_loss'])
    axs[1].plot(range(1,len(training_history['G_loss'])+1),training_history['G_loss'])
    axs[1].set_title('D and G Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(training_history['G_loss'])+1),len(training_history['G_loss'])/10)
    axs[1].legend(['Discriminator', 'Generator'], loc='best')
    plt.show()

# %%
def predict( X_test, y_test):

    # Generating a predictions from the discriminator over the testing dataset
    y_pred = discriminator.predict(X_test)

    # Formating predictions to remove the one_hot_encoding format
    y_pred = np.argmax(y_pred[1][:,:-1], axis=1)

    print ('\nOverall accuracy: %f%% \n' % (accuracy_score(y_test, y_pred) * 100))
    print ('\nAveP: %f%% \n' % (average_precision_score(y_test, y_pred) * 100))

    class_names = ['Non-nunclei', 'Nuclei']
    print("Classification report:\n %s\n"
          % (classification_report(y_test, y_pred, target_names=class_names)))

    cm = confusion_matrix(y_test, y_pred)

    plt.figure()
    plot_confusion_matrix(cm, class_names, title='Confusion matrix, without normalization')

    plt.figure()
    plot_confusion_matrix(cm, class_names, normalize=True, title='Normalized confusion matrix')

# %%
training_history = {
        'D_loss': [],
        'D_acc': [],
        'G_loss': [],
        'G_acc': [],
        }

optimizer = Adam(0.0002, 0.5)
#build the generator
generator = build_generator()

z = Input(shape=(100,))
img = generator(z)

        # Build discriminator's model
discriminator = build_discriminator()

discriminator.compile(
        loss=['binary_crossentropy', 'categorical_crossentropy'],
        loss_weights=[0.5, 0.5],
        optimizer=optimizer,
        metrics=['accuracy'])
# For the combined model we will only train the generator
discriminator.trainable = False

# For the combined model we will only train the generator
discriminator.trainable = False
# The discriminator takes generated images as input and determines validity
valid, _ =discriminator(img)

# noise as input => generates images => determines validity
combined = Model(z, valid)
combined.compile(
        loss=['binary_crossentropy'], 
        optimizer=optimizer)
# Out:
# WARNING:tensorflow:From c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8192)              827392
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         1731
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 3)         0
# =================================================================
# Total params: 1,051,011
# Trainable params: 1,050,755
# Non-trainable params: 256
# _________________________________________________________________
# WARNING:tensorflow:From c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
if __name__ == '__main__':

    X_train, y_train, X_test, y_test = load_TMI_data()


    start = time.time()
    
    epochs=200
    train(X_train, y_train, X_test, y_test, epochs, batch_size=32, save_interval=5)

    end = time.time()
    print ("\nTraining time: %0.1f minutes \n" % ((end-start) / 60))

    #saved the trained model
    save_model()

    plot_training_history()


    evaluate_discriminator(X_test, y_test)

    predict(X_test, y_test)
# Out:
# WARNING:tensorflow:From c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\keras\engine\training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 0: Training D [loss: 0.7699, acc: 46.88% ] - G [loss: 0.1752, acc: 37.50%]
# Evaluating D [loss:  0.8879, bi-loss: 0.6789, cat-loss: 1.0968, bi-acc: 99.70%, cat-acc: 44.00%]
#
# 1: Training D [loss: 0.6645, acc: 50.00% ] - G [loss: 0.1436, acc: 31.25%]
# Evaluating D [loss:  0.8947, bi-loss: 0.6945, cat-loss: 1.0948, bi-acc: 41.20%, cat-acc: 45.60%]
#
# 2: Training D [loss: 0.9269, acc: 18.75% ] - G [loss: 0.1377, acc: 28.12%]
# Evaluating D [loss:  0.8951, bi-loss: 0.6978, cat-loss: 1.0923, bi-acc: 27.60%, cat-acc: 49.30%]
#
# 3: Training D [loss: 0.9657, acc: 21.88% ] - G [loss: 0.1926, acc: 46.88%]
# Evaluating D [loss:  0.8926, bi-loss: 0.6947, cat-loss: 1.0904, bi-acc: 39.20%, cat-acc: 51.50%]
#
# 4: Training D [loss: 0.7737, acc: 21.88% ] - G [loss: 0.1892, acc: 53.12%]
# Evaluating D [loss:  0.8956, bi-loss: 0.7003, cat-loss: 1.0909, bi-acc: 21.20%, cat-acc: 48.90%]
#
# 5: Training D [loss: 0.9748, acc: 18.75% ] - G [loss: 0.3308, acc: 37.50%]
# Evaluating D [loss:  0.9014, bi-loss: 0.7116, cat-loss: 1.0913, bi-acc: 0.30%, cat-acc: 47.40%]
#
# 6: Training D [loss: 0.6385, acc: 21.88% ] - G [loss: 0.3608, acc: 53.12%]
# Evaluating D [loss:  0.9056, bi-loss: 0.7193, cat-loss: 1.0919, bi-acc: 0.00%, cat-acc: 45.40%]
#
# 7: Training D [loss: 0.8773, acc: 3.12% ] - G [loss: 0.3286, acc: 43.75%]
# Evaluating D [loss:  0.9038, bi-loss: 0.7181, cat-loss: 1.0896, bi-acc: 0.00%, cat-acc: 49.20%]
#
# 8: Training D [loss: 0.6682, acc: 21.88% ] - G [loss: 0.4614, acc: 46.88%]
# Evaluating D [loss:  0.9047, bi-loss: 0.7201, cat-loss: 1.0893, bi-acc: 0.30%, cat-acc: 49.00%]
#
# 9: Training D [loss: 0.6046, acc: 25.00% ] - G [loss: 0.3473, acc: 37.50%]
# Evaluating D [loss:  0.9027, bi-loss: 0.7189, cat-loss: 1.0865, bi-acc: 0.40%, cat-acc: 52.80%]
#
# 10: Training D [loss: 0.7453, acc: 15.62% ] - G [loss: 0.3333, acc: 59.38%]
# Evaluating D [loss:  0.9021, bi-loss: 0.7182, cat-loss: 1.0861, bi-acc: 0.70%, cat-acc: 55.30%]
#
# 11: Training D [loss: 0.7099, acc: 21.88% ] - G [loss: 0.3181, acc: 43.75%]
# Evaluating D [loss:  0.9060, bi-loss: 0.7260, cat-loss: 1.0860, bi-acc: 0.00%, cat-acc: 52.30%]
#
# 12: Training D [loss: 0.9005, acc: 12.50% ] - G [loss: 0.4318, acc: 43.75%]
# Evaluating D [loss:  0.9042, bi-loss: 0.7251, cat-loss: 1.0833, bi-acc: 0.40%, cat-acc: 58.90%]
#
# 13: Training D [loss: 0.5659, acc: 37.50% ] - G [loss: 0.5392, acc: 75.00%]
# Evaluating D [loss:  0.9031, bi-loss: 0.7232, cat-loss: 1.0830, bi-acc: 0.10%, cat-acc: 57.20%]
#
# 14: Training D [loss: 0.6654, acc: 28.12% ] - G [loss: 0.3582, acc: 53.12%]
# Evaluating D [loss:  0.9013, bi-loss: 0.7225, cat-loss: 1.0801, bi-acc: 0.10%, cat-acc: 63.30%]
#
# 15: Training D [loss: 0.6636, acc: 25.00% ] - G [loss: 0.2833, acc: 53.12%]
# Evaluating D [loss:  0.9055, bi-loss: 0.7295, cat-loss: 1.0816, bi-acc: 0.10%, cat-acc: 55.10%]
#
# 16: Training D [loss: 0.7381, acc: 31.25% ] - G [loss: 0.3068, acc: 37.50%]
# Evaluating D [loss:  0.9063, bi-loss: 0.7316, cat-loss: 1.0810, bi-acc: 0.00%, cat-acc: 50.20%]
#
# 17: Training D [loss: 0.8543, acc: 15.62% ] - G [loss: 0.4316, acc: 37.50%]
# Evaluating D [loss:  0.9078, bi-loss: 0.7336, cat-loss: 1.0819, bi-acc: 0.20%, cat-acc: 44.20%]
#
# 18: Training D [loss: 0.7495, acc: 25.00% ] - G [loss: 0.3818, acc: 43.75%]
# Evaluating D [loss:  0.9067, bi-loss: 0.7330, cat-loss: 1.0804, bi-acc: 0.30%, cat-acc: 46.50%]
#
# 19: Training D [loss: 0.8797, acc: 18.75% ] - G [loss: 0.3830, acc: 28.12%]
# Evaluating D [loss:  0.9074, bi-loss: 0.7364, cat-loss: 1.0783, bi-acc: 0.00%, cat-acc: 50.00%]
#
# 20: Training D [loss: 0.7807, acc: 18.75% ] - G [loss: 0.3671, acc: 53.12%]
# Evaluating D [loss:  0.9068, bi-loss: 0.7361, cat-loss: 1.0775, bi-acc: 0.00%, cat-acc: 50.70%]
#
# 21: Training D [loss: 0.6766, acc: 25.00% ] - G [loss: 0.4692, acc: 43.75%]
# Evaluating D [loss:  0.9098, bi-loss: 0.7405, cat-loss: 1.0790, bi-acc: 0.00%, cat-acc: 45.50%]
#
# 22: Training D [loss: 0.7725, acc: 37.50% ] - G [loss: 0.4992, acc: 40.62%]
# Evaluating D [loss:  0.9087, bi-loss: 0.7362, cat-loss: 1.0812, bi-acc: 0.00%, cat-acc: 40.60%]
#
# 23: Training D [loss: 0.9807, acc: 6.25% ] - G [loss: 0.4642, acc: 37.50%]
# Evaluating D [loss:  0.9045, bi-loss: 0.7292, cat-loss: 1.0797, bi-acc: 0.10%, cat-acc: 44.30%]
#
# 24: Training D [loss: 0.7176, acc: 18.75% ] - G [loss: 0.3790, acc: 43.75%]
# Evaluating D [loss:  0.9031, bi-loss: 0.7259, cat-loss: 1.0803, bi-acc: 0.70%, cat-acc: 41.00%]
#
# 25: Training D [loss: 0.9981, acc: 12.50% ] - G [loss: 0.5097, acc: 37.50%]
# Evaluating D [loss:  0.9025, bi-loss: 0.7260, cat-loss: 1.0790, bi-acc: 0.40%, cat-acc: 48.60%]
#
# 26: Training D [loss: 0.7936, acc: 12.50% ] - G [loss: 0.6159, acc: 62.50%]
# Evaluating D [loss:  0.9036, bi-loss: 0.7289, cat-loss: 1.0784, bi-acc: 0.30%, cat-acc: 48.50%]
#
# 27: Training D [loss: 0.6521, acc: 31.25% ] - G [loss: 0.6458, acc: 46.88%]
# Evaluating D [loss:  0.9027, bi-loss: 0.7280, cat-loss: 1.0774, bi-acc: 0.00%, cat-acc: 50.20%]
#
# 28: Training D [loss: 0.7899, acc: 9.38% ] - G [loss: 0.2890, acc: 50.00%]
# Evaluating D [loss:  0.9001, bi-loss: 0.7246, cat-loss: 1.0756, bi-acc: 0.50%, cat-acc: 54.60%]
#
# 29: Training D [loss: 0.7883, acc: 31.25% ] - G [loss: 0.5203, acc: 37.50%]
# Evaluating D [loss:  0.9002, bi-loss: 0.7257, cat-loss: 1.0748, bi-acc: 1.20%, cat-acc: 58.80%]
#
# 30: Training D [loss: 0.9016, acc: 12.50% ] - G [loss: 0.6502, acc: 46.88%]
# Evaluating D [loss:  0.8964, bi-loss: 0.7193, cat-loss: 1.0735, bi-acc: 2.40%, cat-acc: 67.40%]
#
# 31: Training D [loss: 0.5149, acc: 46.88% ] - G [loss: 0.8035, acc: 31.25%]
# Evaluating D [loss:  0.9009, bi-loss: 0.7240, cat-loss: 1.0778, bi-acc: 1.30%, cat-acc: 54.90%]
#
# 32: Training D [loss: 0.7055, acc: 21.88% ] - G [loss: 0.6397, acc: 40.62%]
# Evaluating D [loss:  0.9020, bi-loss: 0.7249, cat-loss: 1.0791, bi-acc: 0.10%, cat-acc: 45.70%]
#
# 33: Training D [loss: 0.7712, acc: 21.88% ] - G [loss: 0.6626, acc: 37.50%]
# Evaluating D [loss:  0.9002, bi-loss: 0.7213, cat-loss: 1.0791, bi-acc: 0.30%, cat-acc: 53.80%]
#
# 34: Training D [loss: 0.7274, acc: 31.25% ] - G [loss: 0.4035, acc: 43.75%]
# Evaluating D [loss:  0.8974, bi-loss: 0.7189, cat-loss: 1.0758, bi-acc: 1.80%, cat-acc: 64.40%]
#
# 35: Training D [loss: 0.6765, acc: 28.12% ] - G [loss: 0.2934, acc: 43.75%]
# Evaluating D [loss:  0.8991, bi-loss: 0.7223, cat-loss: 1.0759, bi-acc: 1.20%, cat-acc: 62.00%]
#
# 36: Training D [loss: 0.8331, acc: 12.50% ] - G [loss: 0.5530, acc: 50.00%]
# Evaluating D [loss:  0.9003, bi-loss: 0.7234, cat-loss: 1.0772, bi-acc: 0.90%, cat-acc: 62.60%]
#
# 37: Training D [loss: 0.8319, acc: 18.75% ] - G [loss: 0.5317, acc: 40.62%]
# Evaluating D [loss:  0.8986, bi-loss: 0.7206, cat-loss: 1.0765, bi-acc: 0.60%, cat-acc: 63.80%]
#
# 38: Training D [loss: 0.7980, acc: 21.88% ] - G [loss: 0.4943, acc: 31.25%]
# Evaluating D [loss:  0.8990, bi-loss: 0.7217, cat-loss: 1.0762, bi-acc: 0.10%, cat-acc: 65.20%]
#
# 39: Training D [loss: 0.7137, acc: 25.00% ] - G [loss: 0.4039, acc: 31.25%]
# Evaluating D [loss:  0.8985, bi-loss: 0.7213, cat-loss: 1.0758, bi-acc: 1.80%, cat-acc: 66.90%]
#
# 40: Training D [loss: 0.8998, acc: 9.38% ] - G [loss: 0.3647, acc: 53.12%]
# Evaluating D [loss:  0.8985, bi-loss: 0.7208, cat-loss: 1.0761, bi-acc: 0.70%, cat-acc: 67.00%]
#
# 41: Training D [loss: 0.7061, acc: 12.50% ] - G [loss: 0.3096, acc: 62.50%]
# Evaluating D [loss:  0.8992, bi-loss: 0.7222, cat-loss: 1.0761, bi-acc: 0.10%, cat-acc: 66.20%]
#
# 42: Training D [loss: 0.8183, acc: 12.50% ] - G [loss: 0.4638, acc: 59.38%]
# Evaluating D [loss:  0.8995, bi-loss: 0.7235, cat-loss: 1.0754, bi-acc: 0.10%, cat-acc: 67.80%]
#
# 43: Training D [loss: 0.8266, acc: 12.50% ] - G [loss: 0.3581, acc: 62.50%]
# Evaluating D [loss:  0.9001, bi-loss: 0.7250, cat-loss: 1.0752, bi-acc: 0.20%, cat-acc: 65.90%]
#
# 44: Training D [loss: 0.8124, acc: 18.75% ] - G [loss: 0.5827, acc: 53.12%]
# Evaluating D [loss:  0.9028, bi-loss: 0.7289, cat-loss: 1.0767, bi-acc: 0.00%, cat-acc: 64.40%]
#
# 45: Training D [loss: 0.7381, acc: 15.62% ] - G [loss: 0.4613, acc: 59.38%]
# Evaluating D [loss:  0.9007, bi-loss: 0.7248, cat-loss: 1.0767, bi-acc: 0.00%, cat-acc: 64.10%]
#
# 46: Training D [loss: 0.7067, acc: 25.00% ] - G [loss: 0.4364, acc: 43.75%]
# Evaluating D [loss:  0.8980, bi-loss: 0.7215, cat-loss: 1.0746, bi-acc: 0.00%, cat-acc: 74.50%]
#
# 47: Training D [loss: 0.7335, acc: 18.75% ] - G [loss: 0.4026, acc: 56.25%]
# Evaluating D [loss:  0.8969, bi-loss: 0.7195, cat-loss: 1.0743, bi-acc: 1.10%, cat-acc: 77.80%]
#
# 48: Training D [loss: 0.7328, acc: 15.62% ] - G [loss: 0.5285, acc: 46.88%]
# Evaluating D [loss:  0.8978, bi-loss: 0.7198, cat-loss: 1.0758, bi-acc: 1.00%, cat-acc: 75.30%]
#
# 49: Training D [loss: 0.6528, acc: 21.88% ] - G [loss: 0.6186, acc: 59.38%]
# Evaluating D [loss:  0.8990, bi-loss: 0.7209, cat-loss: 1.0771, bi-acc: 0.80%, cat-acc: 70.50%]
#
# 50: Training D [loss: 0.8459, acc: 12.50% ] - G [loss: 0.5177, acc: 46.88%]
# Evaluating D [loss:  0.8985, bi-loss: 0.7205, cat-loss: 1.0766, bi-acc: 0.90%, cat-acc: 71.20%]
#
# 51: Training D [loss: 0.6123, acc: 37.50% ] - G [loss: 0.4972, acc: 56.25%]
# Evaluating D [loss:  0.8995, bi-loss: 0.7223, cat-loss: 1.0767, bi-acc: 0.40%, cat-acc: 72.50%]
#
# 52: Training D [loss: 0.8723, acc: 18.75% ] - G [loss: 0.5289, acc: 40.62%]
# Evaluating D [loss:  0.9003, bi-loss: 0.7234, cat-loss: 1.0771, bi-acc: 0.00%, cat-acc: 74.40%]
#
# 53: Training D [loss: 0.6484, acc: 28.12% ] - G [loss: 0.5728, acc: 37.50%]
# Evaluating D [loss:  0.9006, bi-loss: 0.7228, cat-loss: 1.0784, bi-acc: 0.00%, cat-acc: 74.00%]
#
# 54: Training D [loss: 0.7314, acc: 21.88% ] - G [loss: 0.4802, acc: 50.00%]
# Evaluating D [loss:  0.8991, bi-loss: 0.7199, cat-loss: 1.0783, bi-acc: 0.00%, cat-acc: 75.80%]
#
# 55: Training D [loss: 0.7245, acc: 9.38% ] - G [loss: 0.4082, acc: 40.62%]
# Evaluating D [loss:  0.8981, bi-loss: 0.7195, cat-loss: 1.0767, bi-acc: 0.00%, cat-acc: 80.00%]
#
# 56: Training D [loss: 0.6591, acc: 31.25% ] - G [loss: 0.5824, acc: 37.50%]
# Evaluating D [loss:  0.8965, bi-loss: 0.7180, cat-loss: 1.0749, bi-acc: 0.00%, cat-acc: 85.40%]
#
# 57: Training D [loss: 0.7657, acc: 21.88% ] - G [loss: 0.5347, acc: 56.25%]
# Evaluating D [loss:  0.8954, bi-loss: 0.7165, cat-loss: 1.0743, bi-acc: 0.00%, cat-acc: 87.80%]
#
# 58: Training D [loss: 0.7083, acc: 12.50% ] - G [loss: 0.5835, acc: 46.88%]
# Evaluating D [loss:  0.8953, bi-loss: 0.7170, cat-loss: 1.0736, bi-acc: 0.00%, cat-acc: 87.80%]
#
# 59: Training D [loss: 0.6325, acc: 18.75% ] - G [loss: 0.4310, acc: 40.62%]
# Evaluating D [loss:  0.8961, bi-loss: 0.7189, cat-loss: 1.0733, bi-acc: 0.00%, cat-acc: 85.70%]
#
# 60: Training D [loss: 0.8273, acc: 9.38% ] - G [loss: 0.5425, acc: 43.75%]
# Evaluating D [loss:  0.8956, bi-loss: 0.7171, cat-loss: 1.0741, bi-acc: 0.20%, cat-acc: 87.40%]
#
# 61: Training D [loss: 0.6416, acc: 12.50% ] - G [loss: 0.7062, acc: 56.25%]
# Evaluating D [loss:  0.8959, bi-loss: 0.7162, cat-loss: 1.0756, bi-acc: 0.40%, cat-acc: 85.90%]
#
# 62: Training D [loss: 0.5655, acc: 28.12% ] - G [loss: 0.5287, acc: 50.00%]
# Evaluating D [loss:  0.8956, bi-loss: 0.7152, cat-loss: 1.0759, bi-acc: 0.20%, cat-acc: 85.10%]
#
# 63: Training D [loss: 0.6689, acc: 18.75% ] - G [loss: 0.5671, acc: 43.75%]
# Evaluating D [loss:  0.8963, bi-loss: 0.7166, cat-loss: 1.0760, bi-acc: 0.00%, cat-acc: 85.70%]
#
# 64: Training D [loss: 0.5988, acc: 25.00% ] - G [loss: 0.5362, acc: 34.38%]
# Evaluating D [loss:  0.8964, bi-loss: 0.7170, cat-loss: 1.0759, bi-acc: 0.00%, cat-acc: 84.60%]
#
# 65: Training D [loss: 0.7295, acc: 25.00% ] - G [loss: 0.4763, acc: 40.62%]
# Evaluating D [loss:  0.8955, bi-loss: 0.7156, cat-loss: 1.0755, bi-acc: 1.00%, cat-acc: 85.00%]
#
# 66: Training D [loss: 0.6069, acc: 21.88% ] - G [loss: 0.5508, acc: 53.12%]
# Evaluating D [loss:  0.8958, bi-loss: 0.7169, cat-loss: 1.0747, bi-acc: 0.50%, cat-acc: 87.40%]
#
# 67: Training D [loss: 0.6651, acc: 15.62% ] - G [loss: 0.5797, acc: 50.00%]
# Evaluating D [loss:  0.8951, bi-loss: 0.7163, cat-loss: 1.0738, bi-acc: 0.60%, cat-acc: 89.50%]
#
# 68: Training D [loss: 0.5614, acc: 28.12% ] - G [loss: 0.5374, acc: 53.12%]
# Evaluating D [loss:  0.8941, bi-loss: 0.7137, cat-loss: 1.0745, bi-acc: 0.20%, cat-acc: 88.90%]
#
# 69: Training D [loss: 0.6353, acc: 28.12% ] - G [loss: 0.5843, acc: 59.38%]
# Evaluating D [loss:  0.8936, bi-loss: 0.7130, cat-loss: 1.0742, bi-acc: 0.00%, cat-acc: 90.50%]
#
# 70: Training D [loss: 0.5942, acc: 15.62% ] - G [loss: 0.4742, acc: 37.50%]
# Evaluating D [loss:  0.8932, bi-loss: 0.7133, cat-loss: 1.0730, bi-acc: 0.20%, cat-acc: 91.10%]
#
# 71: Training D [loss: 0.6224, acc: 31.25% ] - G [loss: 0.4770, acc: 65.62%]
# Evaluating D [loss:  0.8943, bi-loss: 0.7151, cat-loss: 1.0735, bi-acc: 0.20%, cat-acc: 90.90%]
#
# 72: Training D [loss: 0.6280, acc: 18.75% ] - G [loss: 0.6212, acc: 46.88%]
# Evaluating D [loss:  0.8938, bi-loss: 0.7144, cat-loss: 1.0732, bi-acc: 0.50%, cat-acc: 89.40%]
#
# 73: Training D [loss: 0.5951, acc: 15.62% ] - G [loss: 0.6138, acc: 46.88%]
# Evaluating D [loss:  0.8937, bi-loss: 0.7137, cat-loss: 1.0737, bi-acc: 1.10%, cat-acc: 88.60%]
#
# 74: Training D [loss: 0.7176, acc: 31.25% ] - G [loss: 0.4848, acc: 43.75%]
# Evaluating D [loss:  0.8930, bi-loss: 0.7117, cat-loss: 1.0744, bi-acc: 1.10%, cat-acc: 87.30%]
#
# 75: Training D [loss: 0.6068, acc: 34.38% ] - G [loss: 0.5784, acc: 37.50%]
# Evaluating D [loss:  0.8930, bi-loss: 0.7122, cat-loss: 1.0739, bi-acc: 1.20%, cat-acc: 88.30%]
#
# 76: Training D [loss: 0.5804, acc: 34.38% ] - G [loss: 0.7153, acc: 43.75%]
# Evaluating D [loss:  0.8948, bi-loss: 0.7159, cat-loss: 1.0737, bi-acc: 0.50%, cat-acc: 88.20%]
#
# 77: Training D [loss: 0.6815, acc: 9.38% ] - G [loss: 0.5980, acc: 31.25%]
# Evaluating D [loss:  0.8954, bi-loss: 0.7177, cat-loss: 1.0730, bi-acc: 0.00%, cat-acc: 87.60%]
#
# 78: Training D [loss: 0.6715, acc: 28.12% ] - G [loss: 0.6083, acc: 31.25%]
# Evaluating D [loss:  0.8942, bi-loss: 0.7156, cat-loss: 1.0727, bi-acc: 0.00%, cat-acc: 88.80%]
#
# 79: Training D [loss: 0.6734, acc: 15.62% ] - G [loss: 0.6384, acc: 53.12%]
# Evaluating D [loss:  0.8920, bi-loss: 0.7113, cat-loss: 1.0727, bi-acc: 0.30%, cat-acc: 90.00%]
#
# 80: Training D [loss: 0.6502, acc: 15.62% ] - G [loss: 0.5993, acc: 40.62%]
# Evaluating D [loss:  0.8920, bi-loss: 0.7114, cat-loss: 1.0725, bi-acc: 0.40%, cat-acc: 90.80%]
#
# 81: Training D [loss: 0.4587, acc: 43.75% ] - G [loss: 0.8673, acc: 53.12%]
# Evaluating D [loss:  0.8948, bi-loss: 0.7153, cat-loss: 1.0742, bi-acc: 0.00%, cat-acc: 87.90%]
#
# 82: Training D [loss: 0.5428, acc: 21.88% ] - G [loss: 0.5597, acc: 37.50%]
# Evaluating D [loss:  0.8950, bi-loss: 0.7153, cat-loss: 1.0748, bi-acc: 0.00%, cat-acc: 85.50%]
#
# 83: Training D [loss: 0.6384, acc: 12.50% ] - G [loss: 0.6120, acc: 40.62%]
# Evaluating D [loss:  0.8944, bi-loss: 0.7144, cat-loss: 1.0744, bi-acc: 0.10%, cat-acc: 85.90%]
#
# 84: Training D [loss: 0.5911, acc: 21.88% ] - G [loss: 0.4963, acc: 56.25%]
# Evaluating D [loss:  0.8947, bi-loss: 0.7150, cat-loss: 1.0744, bi-acc: 0.10%, cat-acc: 85.40%]
#
# 85: Training D [loss: 0.6668, acc: 21.88% ] - G [loss: 0.5428, acc: 31.25%]
# Evaluating D [loss:  0.8952, bi-loss: 0.7167, cat-loss: 1.0738, bi-acc: 0.00%, cat-acc: 87.10%]
#
# 86: Training D [loss: 0.5649, acc: 28.12% ] - G [loss: 0.6655, acc: 34.38%]
# Evaluating D [loss:  0.8945, bi-loss: 0.7163, cat-loss: 1.0727, bi-acc: 0.00%, cat-acc: 86.10%]
#
# 87: Training D [loss: 0.4755, acc: 34.38% ] - G [loss: 0.5810, acc: 43.75%]
# Evaluating D [loss:  0.8932, bi-loss: 0.7143, cat-loss: 1.0721, bi-acc: 0.00%, cat-acc: 85.00%]
#
# 88: Training D [loss: 0.6074, acc: 25.00% ] - G [loss: 0.6338, acc: 40.62%]
# Evaluating D [loss:  0.8932, bi-loss: 0.7142, cat-loss: 1.0722, bi-acc: 0.00%, cat-acc: 87.10%]
#
# 89: Training D [loss: 0.5969, acc: 34.38% ] - G [loss: 0.4594, acc: 46.88%]
# Evaluating D [loss:  0.8929, bi-loss: 0.7144, cat-loss: 1.0714, bi-acc: 0.00%, cat-acc: 88.40%]
#
# 90: Training D [loss: 0.6524, acc: 12.50% ] - G [loss: 0.4215, acc: 53.12%]
# Evaluating D [loss:  0.8933, bi-loss: 0.7163, cat-loss: 1.0703, bi-acc: 0.00%, cat-acc: 88.60%]
#
# 91: Training D [loss: 0.6243, acc: 31.25% ] - G [loss: 0.5925, acc: 50.00%]
# Evaluating D [loss:  0.8933, bi-loss: 0.7166, cat-loss: 1.0700, bi-acc: 0.00%, cat-acc: 86.80%]
#
# 92: Training D [loss: 0.6757, acc: 9.38% ] - G [loss: 0.7692, acc: 40.62%]
# Evaluating D [loss:  0.8918, bi-loss: 0.7142, cat-loss: 1.0693, bi-acc: 0.10%, cat-acc: 83.30%]
#
# 93: Training D [loss: 0.5540, acc: 37.50% ] - G [loss: 0.4809, acc: 40.62%]
# Evaluating D [loss:  0.8913, bi-loss: 0.7123, cat-loss: 1.0703, bi-acc: 0.20%, cat-acc: 78.70%]
#
# 94: Training D [loss: 0.6409, acc: 21.88% ] - G [loss: 0.4429, acc: 46.88%]
# Evaluating D [loss:  0.8927, bi-loss: 0.7142, cat-loss: 1.0712, bi-acc: 0.30%, cat-acc: 76.70%]
# 95: Training D [loss: 0.6686, acc: 15.62% ] - G [loss: 0.7108, acc: 43.75%]
# Evaluating D [loss:  0.8947, bi-loss: 0.7176, cat-loss: 1.0718, bi-acc: 0.10%, cat-acc: 80.20%]
#
# 96: Training D [loss: 0.5376, acc: 46.88% ] - G [loss: 1.0362, acc: 46.88%]
# Evaluating D [loss:  0.8929, bi-loss: 0.7153, cat-loss: 1.0704, bi-acc: 0.00%, cat-acc: 84.60%]
#
# 97: Training D [loss: 0.5560, acc: 28.12% ] - G [loss: 0.5644, acc: 50.00%]
# Evaluating D [loss:  0.8906, bi-loss: 0.7111, cat-loss: 1.0700, bi-acc: 0.20%, cat-acc: 83.40%]
#
# 98: Training D [loss: 0.5379, acc: 25.00% ] - G [loss: 0.2943, acc: 59.38%]
# Evaluating D [loss:  0.8910, bi-loss: 0.7111, cat-loss: 1.0709, bi-acc: 0.50%, cat-acc: 80.20%]
#
# 99: Training D [loss: 0.7741, acc: 15.62% ] - G [loss: 0.3627, acc: 50.00%]
# Evaluating D [loss:  0.8908, bi-loss: 0.7122, cat-loss: 1.0694, bi-acc: 0.40%, cat-acc: 80.20%]
#
# 100: Training D [loss: 0.6054, acc: 18.75% ] - G [loss: 0.5049, acc: 43.75%]
# Evaluating D [loss:  0.8914, bi-loss: 0.7148, cat-loss: 1.0679, bi-acc: 0.00%, cat-acc: 81.70%]
#
# 101: Training D [loss: 0.6221, acc: 9.38% ] - G [loss: 0.4647, acc: 40.62%]
# Evaluating D [loss:  0.8909, bi-loss: 0.7150, cat-loss: 1.0668, bi-acc: 0.00%, cat-acc: 85.50%]
#
# 102: Training D [loss: 0.5873, acc: 28.12% ] - G [loss: 0.4268, acc: 34.38%]
# Evaluating D [loss:  0.8911, bi-loss: 0.7162, cat-loss: 1.0660, bi-acc: 0.00%, cat-acc: 87.60%]
#
# 103: Training D [loss: 0.7480, acc: 9.38% ] - G [loss: 0.7385, acc: 34.38%]
# Evaluating D [loss:  0.8904, bi-loss: 0.7150, cat-loss: 1.0658, bi-acc: 0.10%, cat-acc: 90.90%]
#
# 104: Training D [loss: 0.6558, acc: 15.62% ] - G [loss: 0.9133, acc: 53.12%]
# Evaluating D [loss:  0.8893, bi-loss: 0.7128, cat-loss: 1.0658, bi-acc: 0.30%, cat-acc: 90.80%]
#
# 105: Training D [loss: 0.4878, acc: 31.25% ] - G [loss: 0.5686, acc: 62.50%]
# Evaluating D [loss:  0.8882, bi-loss: 0.7114, cat-loss: 1.0649, bi-acc: 0.90%, cat-acc: 88.70%]
#
# 106: Training D [loss: 0.5589, acc: 25.00% ] - G [loss: 0.3950, acc: 43.75%]
# Evaluating D [loss:  0.8872, bi-loss: 0.7099, cat-loss: 1.0644, bi-acc: 1.00%, cat-acc: 89.40%]
#
# 107: Training D [loss: 0.7596, acc: 21.88% ] - G [loss: 0.5170, acc: 46.88%]
# Evaluating D [loss:  0.8889, bi-loss: 0.7125, cat-loss: 1.0652, bi-acc: 0.20%, cat-acc: 89.80%]
#
# 108: Training D [loss: 0.5749, acc: 31.25% ] - G [loss: 0.5621, acc: 46.88%]
# Evaluating D [loss:  0.8906, bi-loss: 0.7144, cat-loss: 1.0669, bi-acc: 0.00%, cat-acc: 89.30%]
#
# 109: Training D [loss: 0.4747, acc: 25.00% ] - G [loss: 0.6654, acc: 50.00%]
# Evaluating D [loss:  0.8909, bi-loss: 0.7141, cat-loss: 1.0677, bi-acc: 0.00%, cat-acc: 89.60%]
#
# 110: Training D [loss: 0.6154, acc: 18.75% ] - G [loss: 0.5741, acc: 43.75%]
# Evaluating D [loss:  0.8906, bi-loss: 0.7127, cat-loss: 1.0686, bi-acc: 0.00%, cat-acc: 91.10%]
#
# 111: Training D [loss: 0.5234, acc: 25.00% ] - G [loss: 0.6741, acc: 34.38%]
# Evaluating D [loss:  0.8910, bi-loss: 0.7136, cat-loss: 1.0683, bi-acc: 0.00%, cat-acc: 90.90%]
#
# 112: Training D [loss: 0.5472, acc: 28.12% ] - G [loss: 0.6943, acc: 50.00%]
# Evaluating D [loss:  0.8924, bi-loss: 0.7152, cat-loss: 1.0695, bi-acc: 0.30%, cat-acc: 89.50%]
#
# 113: Training D [loss: 0.5816, acc: 21.88% ] - G [loss: 0.4726, acc: 40.62%]
# Evaluating D [loss:  0.8931, bi-loss: 0.7156, cat-loss: 1.0707, bi-acc: 0.60%, cat-acc: 89.20%]
#
# 114: Training D [loss: 0.6244, acc: 15.62% ] - G [loss: 0.4790, acc: 65.62%]
# Evaluating D [loss:  0.8938, bi-loss: 0.7161, cat-loss: 1.0714, bi-acc: 0.00%, cat-acc: 89.80%]
#
# 115: Training D [loss: 0.5286, acc: 21.88% ] - G [loss: 0.5687, acc: 50.00%]
# Evaluating D [loss:  0.8952, bi-loss: 0.7183, cat-loss: 1.0720, bi-acc: 0.00%, cat-acc: 90.50%]
#
# 116: Training D [loss: 0.5384, acc: 15.62% ] - G [loss: 0.6709, acc: 56.25%]
# Evaluating D [loss:  0.8950, bi-loss: 0.7177, cat-loss: 1.0722, bi-acc: 0.00%, cat-acc: 91.20%]
#
# 117: Training D [loss: 0.5376, acc: 18.75% ] - G [loss: 0.6327, acc: 50.00%]
# Evaluating D [loss:  0.8938, bi-loss: 0.7161, cat-loss: 1.0715, bi-acc: 0.00%, cat-acc: 90.80%]
#
# 118: Training D [loss: 0.6328, acc: 12.50% ] - G [loss: 0.2628, acc: 40.62%]
# Evaluating D [loss:  0.8919, bi-loss: 0.7132, cat-loss: 1.0706, bi-acc: 0.10%, cat-acc: 92.20%]
#
# 119: Training D [loss: 0.6802, acc: 18.75% ] - G [loss: 0.6018, acc: 40.62%]
# Evaluating D [loss:  0.8909, bi-loss: 0.7129, cat-loss: 1.0689, bi-acc: 0.70%, cat-acc: 92.10%]
#
# 120: Training D [loss: 0.4850, acc: 43.75% ] - G [loss: 0.4906, acc: 53.12%]
# Evaluating D [loss:  0.8894, bi-loss: 0.7107, cat-loss: 1.0681, bi-acc: 0.30%, cat-acc: 93.00%]
#
# 121: Training D [loss: 0.6554, acc: 28.12% ] - G [loss: 0.2930, acc: 43.75%]
# Evaluating D [loss:  0.8892, bi-loss: 0.7103, cat-loss: 1.0681, bi-acc: 0.20%, cat-acc: 91.90%]
#
# 122: Training D [loss: 0.7242, acc: 18.75% ] - G [loss: 0.6113, acc: 46.88%]
# Evaluating D [loss:  0.8912, bi-loss: 0.7127, cat-loss: 1.0696, bi-acc: 0.20%, cat-acc: 90.30%]
#
# 123: Training D [loss: 0.5663, acc: 37.50% ] - G [loss: 0.7967, acc: 40.62%]
# Evaluating D [loss:  0.8924, bi-loss: 0.7143, cat-loss: 1.0705, bi-acc: 0.50%, cat-acc: 89.60%]
#
# 124: Training D [loss: 0.5231, acc: 34.38% ] - G [loss: 0.5149, acc: 50.00%]
# Evaluating D [loss:  0.8923, bi-loss: 0.7139, cat-loss: 1.0708, bi-acc: 0.60%, cat-acc: 89.70%]
#
# 125: Training D [loss: 0.6163, acc: 21.88% ] - G [loss: 0.6184, acc: 43.75%]
# Evaluating D [loss:  0.8946, bi-loss: 0.7164, cat-loss: 1.0729, bi-acc: 0.10%, cat-acc: 89.40%]
#
# 126: Training D [loss: 0.5735, acc: 18.75% ] - G [loss: 0.6038, acc: 62.50%]
# Evaluating D [loss:  0.8943, bi-loss: 0.7153, cat-loss: 1.0734, bi-acc: 0.00%, cat-acc: 90.80%]
#
# 127: Training D [loss: 0.5232, acc: 18.75% ] - G [loss: 0.5827, acc: 46.88%]
# Evaluating D [loss:  0.8926, bi-loss: 0.7140, cat-loss: 1.0713, bi-acc: 0.00%, cat-acc: 92.90%]
#
# 128: Training D [loss: 0.4923, acc: 34.38% ] - G [loss: 0.4834, acc: 40.62%]
# Evaluating D [loss:  0.8919, bi-loss: 0.7139, cat-loss: 1.0698, bi-acc: 0.00%, cat-acc: 93.50%]
#
# 129: Training D [loss: 0.5746, acc: 21.88% ] - G [loss: 0.5498, acc: 59.38%]
# Evaluating D [loss:  0.8920, bi-loss: 0.7143, cat-loss: 1.0697, bi-acc: 0.00%, cat-acc: 92.90%]
#
# 130: Training D [loss: 0.5787, acc: 15.62% ] - G [loss: 0.6290, acc: 59.38%]
# Evaluating D [loss:  0.8918, bi-loss: 0.7142, cat-loss: 1.0694, bi-acc: 0.00%, cat-acc: 90.60%]
#
# 131: Training D [loss: 0.6109, acc: 12.50% ] - G [loss: 0.6516, acc: 43.75%]
# Evaluating D [loss:  0.8911, bi-loss: 0.7131, cat-loss: 1.0690, bi-acc: 0.00%, cat-acc: 91.10%]
#
# 132: Training D [loss: 0.6029, acc: 18.75% ] - G [loss: 0.5671, acc: 56.25%]
# Evaluating D [loss:  0.8906, bi-loss: 0.7117, cat-loss: 1.0696, bi-acc: 0.00%, cat-acc: 94.00%]
#
# 133: Training D [loss: 0.4759, acc: 34.38% ] - G [loss: 0.5664, acc: 59.38%]
# Evaluating D [loss:  0.8909, bi-loss: 0.7114, cat-loss: 1.0703, bi-acc: 0.00%, cat-acc: 93.70%]
#
# 134: Training D [loss: 0.5796, acc: 18.75% ] - G [loss: 0.6711, acc: 46.88%]
# Evaluating D [loss:  0.8909, bi-loss: 0.7121, cat-loss: 1.0697, bi-acc: 0.20%, cat-acc: 94.10%]
#
# 135: Training D [loss: 0.5535, acc: 18.75% ] - G [loss: 0.5667, acc: 59.38%]
# Evaluating D [loss:  0.8905, bi-loss: 0.7115, cat-loss: 1.0695, bi-acc: 0.60%, cat-acc: 94.20%]
#
# 136: Training D [loss: 0.5567, acc: 21.88% ] - G [loss: 0.6771, acc: 40.62%]
# Evaluating D [loss:  0.8906, bi-loss: 0.7122, cat-loss: 1.0690, bi-acc: 0.40%, cat-acc: 94.30%]
#
# 137: Training D [loss: 0.5832, acc: 18.75% ] - G [loss: 0.6837, acc: 50.00%]
# Evaluating D [loss:  0.8910, bi-loss: 0.7129, cat-loss: 1.0691, bi-acc: 0.00%, cat-acc: 94.80%]
#
# 138: Training D [loss: 0.4816, acc: 21.88% ] - G [loss: 0.7684, acc: 46.88%]
# Evaluating D [loss:  0.8916, bi-loss: 0.7139, cat-loss: 1.0693, bi-acc: 0.00%, cat-acc: 95.00%]
#
# 139: Training D [loss: 0.5344, acc: 34.38% ] - G [loss: 0.6364, acc: 59.38%]
# Evaluating D [loss:  0.8904, bi-loss: 0.7115, cat-loss: 1.0693, bi-acc: 0.10%, cat-acc: 95.20%]
#
# 140: Training D [loss: 0.5953, acc: 12.50% ] - G [loss: 0.5498, acc: 56.25%]
# Evaluating D [loss:  0.8896, bi-loss: 0.7095, cat-loss: 1.0698, bi-acc: 0.20%, cat-acc: 95.50%]
#
# 141: Training D [loss: 0.5630, acc: 18.75% ] - G [loss: 0.5325, acc: 43.75%]
# Evaluating D [loss:  0.8897, bi-loss: 0.7097, cat-loss: 1.0696, bi-acc: 0.10%, cat-acc: 95.40%]
#
# 142: Training D [loss: 0.5623, acc: 15.62% ] - G [loss: 0.7231, acc: 40.62%]
# Evaluating D [loss:  0.8908, bi-loss: 0.7119, cat-loss: 1.0697, bi-acc: 0.00%, cat-acc: 95.80%]
#
# 143: Training D [loss: 0.5227, acc: 21.88% ] - G [loss: 0.7153, acc: 53.12%]
# Evaluating D [loss:  0.8910, bi-loss: 0.7122, cat-loss: 1.0697, bi-acc: 0.00%, cat-acc: 95.90%]
#
# 144: Training D [loss: 0.6473, acc: 0.00% ] - G [loss: 0.6597, acc: 56.25%]
# Evaluating D [loss:  0.8900, bi-loss: 0.7104, cat-loss: 1.0696, bi-acc: 0.00%, cat-acc: 95.80%]
#
# 145: Training D [loss: 0.6585, acc: 6.25% ] - G [loss: 0.5804, acc: 50.00%]
# Evaluating D [loss:  0.8894, bi-loss: 0.7098, cat-loss: 1.0691, bi-acc: 0.00%, cat-acc: 95.40%]
#
# 146: Training D [loss: 0.5807, acc: 21.88% ] - G [loss: 0.6369, acc: 50.00%]
# Evaluating D [loss:  0.8883, bi-loss: 0.7083, cat-loss: 1.0682, bi-acc: 0.00%, cat-acc: 95.50%]
#
# 147: Training D [loss: 0.5084, acc: 34.38% ] - G [loss: 0.8003, acc: 46.88%]
# Evaluating D [loss:  0.8881, bi-loss: 0.7080, cat-loss: 1.0681, bi-acc: 0.00%, cat-acc: 95.30%]
#
# 148: Training D [loss: 0.4770, acc: 34.38% ] - G [loss: 0.4731, acc: 43.75%]
# Evaluating D [loss:  0.8888, bi-loss: 0.7083, cat-loss: 1.0692, bi-acc: 0.00%, cat-acc: 94.70%]
#
# 149: Training D [loss: 0.6498, acc: 18.75% ] - G [loss: 0.6011, acc: 56.25%]
# Evaluating D [loss:  0.8892, bi-loss: 0.7091, cat-loss: 1.0693, bi-acc: 0.00%, cat-acc: 94.10%]
#
# 150: Training D [loss: 0.5950, acc: 6.25% ] - G [loss: 0.8122, acc: 62.50%]
# Evaluating D [loss:  0.8891, bi-loss: 0.7091, cat-loss: 1.0691, bi-acc: 0.00%, cat-acc: 94.00%]
#
# 151: Training D [loss: 0.4701, acc: 31.25% ] - G [loss: 0.4831, acc: 50.00%]
# Evaluating D [loss:  0.8886, bi-loss: 0.7084, cat-loss: 1.0689, bi-acc: 0.00%, cat-acc: 93.40%]
#
# 152: Training D [loss: 0.5560, acc: 28.12% ] - G [loss: 0.5054, acc: 53.12%]
# Evaluating D [loss:  0.8886, bi-loss: 0.7088, cat-loss: 1.0684, bi-acc: 0.00%, cat-acc: 93.10%]
#
# 153: Training D [loss: 0.5131, acc: 25.00% ] - G [loss: 0.5029, acc: 50.00%]
# Evaluating D [loss:  0.8887, bi-loss: 0.7084, cat-loss: 1.0690, bi-acc: 0.00%, cat-acc: 93.70%]
#
# 154: Training D [loss: 0.6026, acc: 12.50% ] - G [loss: 0.5773, acc: 53.12%]
# Evaluating D [loss:  0.8884, bi-loss: 0.7083, cat-loss: 1.0685, bi-acc: 0.40%, cat-acc: 94.20%]
#
# 155: Training D [loss: 0.5604, acc: 6.25% ] - G [loss: 0.6844, acc: 53.12%]
# Evaluating D [loss:  0.8877, bi-loss: 0.7077, cat-loss: 1.0678, bi-acc: 0.80%, cat-acc: 94.00%]
#
# 156: Training D [loss: 0.5062, acc: 25.00% ] - G [loss: 0.8122, acc: 59.38%]
# Evaluating D [loss:  0.8883, bi-loss: 0.7088, cat-loss: 1.0677, bi-acc: 0.10%, cat-acc: 93.80%]
#
# 157: Training D [loss: 0.5144, acc: 25.00% ] - G [loss: 0.7080, acc: 43.75%]
# Evaluating D [loss:  0.8882, bi-loss: 0.7088, cat-loss: 1.0676, bi-acc: 0.00%, cat-acc: 93.40%]
#
# 158: Training D [loss: 0.4848, acc: 40.62% ] - G [loss: 0.6756, acc: 43.75%]
# Evaluating D [loss:  0.8876, bi-loss: 0.7085, cat-loss: 1.0668, bi-acc: 0.00%, cat-acc: 92.90%]
#
# 159: Training D [loss: 0.5175, acc: 28.12% ] - G [loss: 0.5851, acc: 46.88%]
# Evaluating D [loss:  0.8876, bi-loss: 0.7081, cat-loss: 1.0670, bi-acc: 0.00%, cat-acc: 92.90%]
#
# 160: Training D [loss: 0.5579, acc: 25.00% ] - G [loss: 0.5796, acc: 37.50%]
# Evaluating D [loss:  0.8888, bi-loss: 0.7091, cat-loss: 1.0684, bi-acc: 0.00%, cat-acc: 93.00%]
#
# 161: Training D [loss: 0.5998, acc: 9.38% ] - G [loss: 0.7054, acc: 50.00%]
# Evaluating D [loss:  0.8887, bi-loss: 0.7090, cat-loss: 1.0684, bi-acc: 0.00%, cat-acc: 92.30%]
#
# 162: Training D [loss: 0.5021, acc: 28.12% ] - G [loss: 0.6771, acc: 59.38%]
# Evaluating D [loss:  0.8882, bi-loss: 0.7081, cat-loss: 1.0682, bi-acc: 0.00%, cat-acc: 91.20%]
#
# 163: Training D [loss: 0.4936, acc: 21.88% ] - G [loss: 0.5247, acc: 43.75%]
# Evaluating D [loss:  0.8883, bi-loss: 0.7078, cat-loss: 1.0687, bi-acc: 0.00%, cat-acc: 90.10%]
#
# 164: Training D [loss: 0.5716, acc: 25.00% ] - G [loss: 0.5552, acc: 43.75%]
# Evaluating D [loss:  0.8891, bi-loss: 0.7085, cat-loss: 1.0697, bi-acc: 0.00%, cat-acc: 90.70%]
#
# 165: Training D [loss: 0.5248, acc: 28.12% ] - G [loss: 0.7072, acc: 53.12%]
# Evaluating D [loss:  0.8884, bi-loss: 0.7072, cat-loss: 1.0697, bi-acc: 0.00%, cat-acc: 89.90%]
#
# 166: Training D [loss: 0.4552, acc: 21.88% ] - G [loss: 0.6064, acc: 59.38%]
# Evaluating D [loss:  0.8872, bi-loss: 0.7054, cat-loss: 1.0690, bi-acc: 0.00%, cat-acc: 90.10%]
#
# 167: Training D [loss: 0.5577, acc: 25.00% ] - G [loss: 0.4717, acc: 43.75%]
# Evaluating D [loss:  0.8864, bi-loss: 0.7048, cat-loss: 1.0681, bi-acc: 0.10%, cat-acc: 89.90%]
#
# 168: Training D [loss: 0.5546, acc: 18.75% ] - G [loss: 0.4419, acc: 50.00%]
# Evaluating D [loss:  0.8865, bi-loss: 0.7052, cat-loss: 1.0678, bi-acc: 0.00%, cat-acc: 90.90%]
#
# 169: Training D [loss: 0.4887, acc: 21.88% ] - G [loss: 0.6399, acc: 62.50%]
# Evaluating D [loss:  0.8862, bi-loss: 0.7052, cat-loss: 1.0671, bi-acc: 0.00%, cat-acc: 90.50%]
#
# 170: Training D [loss: 0.4964, acc: 15.62% ] - G [loss: 0.6459, acc: 50.00%]
# Evaluating D [loss:  0.8863, bi-loss: 0.7050, cat-loss: 1.0676, bi-acc: 0.00%, cat-acc: 89.60%]
#
# 171: Training D [loss: 0.4824, acc: 31.25% ] - G [loss: 0.6116, acc: 62.50%]
# Evaluating D [loss:  0.8869, bi-loss: 0.7058, cat-loss: 1.0681, bi-acc: 0.10%, cat-acc: 88.90%]
#
# 172: Training D [loss: 0.5345, acc: 15.62% ] - G [loss: 0.6250, acc: 53.12%]
# Evaluating D [loss:  0.8871, bi-loss: 0.7062, cat-loss: 1.0681, bi-acc: 0.00%, cat-acc: 87.00%]
#
# 173: Training D [loss: 0.4877, acc: 34.38% ] - G [loss: 0.6934, acc: 40.62%]
# Evaluating D [loss:  0.8867, bi-loss: 0.7056, cat-loss: 1.0677, bi-acc: 0.00%, cat-acc: 84.40%]
#
# 174: Training D [loss: 0.5040, acc: 18.75% ] - G [loss: 0.6488, acc: 53.12%]
# Evaluating D [loss:  0.8866, bi-loss: 0.7056, cat-loss: 1.0675, bi-acc: 0.00%, cat-acc: 83.00%]
#
# 175: Training D [loss: 0.4748, acc: 21.88% ] - G [loss: 0.6302, acc: 53.12%]
# Evaluating D [loss:  0.8869, bi-loss: 0.7066, cat-loss: 1.0672, bi-acc: 0.00%, cat-acc: 82.60%]
#
# 176: Training D [loss: 0.5167, acc: 18.75% ] - G [loss: 0.6109, acc: 50.00%]
# Evaluating D [loss:  0.8856, bi-loss: 0.7048, cat-loss: 1.0663, bi-acc: 0.00%, cat-acc: 81.50%]
#
# 177: Training D [loss: 0.5691, acc: 25.00% ] - G [loss: 0.5965, acc: 46.88%]
# Evaluating D [loss:  0.8860, bi-loss: 0.7054, cat-loss: 1.0667, bi-acc: 0.00%, cat-acc: 82.00%]
#
# 178: Training D [loss: 0.5000, acc: 21.88% ] - G [loss: 0.6520, acc: 53.12%]
# Evaluating D [loss:  0.8863, bi-loss: 0.7058, cat-loss: 1.0668, bi-acc: 0.00%, cat-acc: 83.40%]
#
# 179: Training D [loss: 0.5477, acc: 21.88% ] - G [loss: 0.6330, acc: 50.00%]
# Evaluating D [loss:  0.8866, bi-loss: 0.7060, cat-loss: 1.0672, bi-acc: 0.00%, cat-acc: 85.30%]
#
# 180: Training D [loss: 0.5606, acc: 15.62% ] - G [loss: 0.5919, acc: 37.50%]
# Evaluating D [loss:  0.8862, bi-loss: 0.7059, cat-loss: 1.0665, bi-acc: 0.10%, cat-acc: 89.70%]
#
# 181: Training D [loss: 0.5190, acc: 18.75% ] - G [loss: 0.6174, acc: 43.75%]
# Evaluating D [loss:  0.8864, bi-loss: 0.7064, cat-loss: 1.0664, bi-acc: 0.80%, cat-acc: 90.80%]
#
# 182: Training D [loss: 0.4742, acc: 25.00% ] - G [loss: 0.5275, acc: 59.38%]
# Evaluating D [loss:  0.8868, bi-loss: 0.7071, cat-loss: 1.0666, bi-acc: 1.00%, cat-acc: 91.40%]
#
# 183: Training D [loss: 0.6383, acc: 3.12% ] - G [loss: 0.6736, acc: 50.00%]
# Evaluating D [loss:  0.8865, bi-loss: 0.7062, cat-loss: 1.0667, bi-acc: 0.90%, cat-acc: 91.30%]
#
# 184: Training D [loss: 0.4460, acc: 31.25% ] - G [loss: 0.6574, acc: 53.12%]
# Evaluating D [loss:  0.8861, bi-loss: 0.7059, cat-loss: 1.0663, bi-acc: 0.40%, cat-acc: 91.10%]
#
# 185: Training D [loss: 0.4744, acc: 34.38% ] - G [loss: 0.5527, acc: 53.12%]
# Evaluating D [loss:  0.8863, bi-loss: 0.7060, cat-loss: 1.0665, bi-acc: 0.30%, cat-acc: 91.10%]
#
# 186: Training D [loss: 0.5744, acc: 21.88% ] - G [loss: 0.6417, acc: 43.75%]
# Evaluating D [loss:  0.8861, bi-loss: 0.7065, cat-loss: 1.0657, bi-acc: 0.30%, cat-acc: 91.30%]
#
# 187: Training D [loss: 0.4879, acc: 28.12% ] - G [loss: 0.6530, acc: 56.25%]
# Evaluating D [loss:  0.8863, bi-loss: 0.7069, cat-loss: 1.0657, bi-acc: 0.20%, cat-acc: 91.80%]
#
# 188: Training D [loss: 0.4781, acc: 25.00% ] - G [loss: 0.5931, acc: 59.38%]
# Evaluating D [loss:  0.8865, bi-loss: 0.7072, cat-loss: 1.0657, bi-acc: 0.20%, cat-acc: 91.90%]
#
# 189: Training D [loss: 0.5448, acc: 21.88% ] - G [loss: 0.5309, acc: 43.75%]
# Evaluating D [loss:  0.8868, bi-loss: 0.7076, cat-loss: 1.0660, bi-acc: 0.20%, cat-acc: 92.20%]
# 190: Training D [loss: 0.6392, acc: 3.12% ] - G [loss: 0.6209, acc: 62.50%]
# Evaluating D [loss:  0.8867, bi-loss: 0.7069, cat-loss: 1.0666, bi-acc: 0.00%, cat-acc: 92.50%]
#
# 191: Training D [loss: 0.5244, acc: 21.88% ] - G [loss: 0.7155, acc: 46.88%]
# Evaluating D [loss:  0.8866, bi-loss: 0.7069, cat-loss: 1.0664, bi-acc: 0.00%, cat-acc: 93.20%]
#
# 192: Training D [loss: 0.5340, acc: 25.00% ] - G [loss: 0.7921, acc: 53.12%]
# Evaluating D [loss:  0.8864, bi-loss: 0.7070, cat-loss: 1.0658, bi-acc: 0.00%, cat-acc: 93.30%]
#
# 193: Training D [loss: 0.4927, acc: 21.88% ] - G [loss: 0.7389, acc: 56.25%]
# Evaluating D [loss:  0.8865, bi-loss: 0.7075, cat-loss: 1.0655, bi-acc: 0.00%, cat-acc: 93.00%]
#
# 194: Training D [loss: 0.4111, acc: 53.12% ] - G [loss: 0.7751, acc: 56.25%]
# Evaluating D [loss:  0.8863, bi-loss: 0.7068, cat-loss: 1.0658, bi-acc: 0.00%, cat-acc: 93.00%]
#
# 195: Training D [loss: 0.5059, acc: 25.00% ] - G [loss: 0.6205, acc: 56.25%]
# Evaluating D [loss:  0.8861, bi-loss: 0.7063, cat-loss: 1.0660, bi-acc: 0.00%, cat-acc: 93.00%]
#
# 196: Training D [loss: 0.4644, acc: 18.75% ] - G [loss: 0.7468, acc: 46.88%]
# Evaluating D [loss:  0.8860, bi-loss: 0.7061, cat-loss: 1.0659, bi-acc: 0.00%, cat-acc: 92.70%]
#
# 197: Training D [loss: 0.5417, acc: 15.62% ] - G [loss: 0.6880, acc: 34.38%]
# Evaluating D [loss:  0.8855, bi-loss: 0.7050, cat-loss: 1.0659, bi-acc: 0.00%, cat-acc: 92.80%]
#
# 198: Training D [loss: 0.4808, acc: 21.88% ] - G [loss: 0.5724, acc: 50.00%]
# Evaluating D [loss:  0.8852, bi-loss: 0.7047, cat-loss: 1.0657, bi-acc: 0.00%, cat-acc: 93.20%]
#
# 199: Training D [loss: 0.5368, acc: 15.62% ] - G [loss: 0.6514, acc: 53.12%]
# Evaluating D [loss:  0.8853, bi-loss: 0.7047, cat-loss: 1.0659, bi-acc: 0.10%, cat-acc: 93.40%]
#
#
# Training time: 23.0 minutes
# Evaluating D [loss:  0.8853, bi-loss: 0.7047, cat-loss: 1.0659, bi-acc: 0.10%, cat-acc: 93.40%]
#
#
# Overall accuracy: 93.400000%
#
#
# AveP: 88.699639%
#
# Classification report:
#                precision    recall  f1-score   support
#
#  Non-nunclei       0.99      0.88      0.93       500
#       Nuclei       0.89      0.99      0.94       500
#
#    micro avg       0.93      0.93      0.93      1000
#    macro avg       0.94      0.93      0.93      1000
# weighted avg       0.94      0.93      0.93      1000
